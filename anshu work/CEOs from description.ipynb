# %%
import tweepy
import pandas as pd
import numpy as np

# %%
# assign the values accordingly 
consumer_key = "BE5DdAO6CIBYn6cDUG9NH75Tl" 
consumer_secret = "86J34Xsa8sI4PcDU5aVBmiRV9VcfpVLhSLMQj33L2SfNh7vYOl" 
access_token = "3097042092-61MnDb93t4X7sa2Kf2n1DAiy3NZsD5rkxaHBDGG" 
access_token_secret = "CbiPs7XmJ0fsiwViqCf5MtO3KHQ5d9w403byQa8EmKfts"

# %%
# authorization of consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
# set access to user's access key and access secret  
auth.set_access_token(access_token, access_token_secret) 
  
# calling the api  
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
df=pd.read_csv(r"C:\Users\Anshu\Downloads\Output.csv")
df.shape
# Out:
# (216, 5)

# %%
tdf=pd.DataFrame()
ceos=[]
companies=[]
years=[]
handles=[]
descriptions=[]
verified=[]
Actual_CEO=[]

# %%
for i in range(len(df)):
    s=df.Twitter_Descr
    print(s)
# Out:
# 0      Siemens is a technology company focused on ind...
# 1      Apple CEO  Auburn 🏀 🏈 Duke 🏀 National Parks 🏞...
# 2      Lost to two budget teams. Founded the most out...
# 3      The Associated Press writer based in Mexico Ci...
# 4           (He/Him) 💅🏽 Carlos sometimes. Frankie always
#                              ...
# 211                                         VC @ShrugCap
# 212    Member of Congress serving New Hampshire's 1st...
# 213    Congressman in #NH01 | Life-long Manchester Re...
# 214    Fight till the end for what you believe is right.
# 215                                     CEO, Tripadvisor
# Name: Twitter_Descr, Length: 216, dtype: object
# 0      Siemens is a technology company focused on ind...
# 1      Apple CEO  Auburn 🏀 🏈 Duke 🏀 National Parks 🏞...
# 2      Lost to two budget teams. Founded the most out...
# 3      The Associated Press writer based in Mexico Ci...
# 4           (He/Him) 💅🏽 Carlos sometimes. Frankie always
# ...

# %%
df.columns
# Out:
# Index(['CEO', 'Company', 'Handle', 'Twitter_Descr', 'verified'], dtype='object')

# %%
# Function that returns true
# if the word is found
def isWordPresent(sentence, word):
 
    # To convert the word in uppercase
    word = word.upper()
 
    # To convert the complete
    # sentence in uppercase
    sentence = sentence.upper()
 
    # splitting the sentence to list
    lis = sentence.split()
    # checking if word is present
    if(lis.count(word) > 0):
        return True
    else:
        return False
 
# Driver code
Number=0
for i in range(len(df)):
    try : 
        s = df.Twitter_Descr[i]
        word = "CEO"
        ceos.append(df.iloc[i]['CEO'])
        companies.append(df.iloc[i]['Company'])
        #years.append(df.iloc[i]['YEAR'])
        handles.append(df.iloc[i]['Handle'])
        descriptions.append(df.iloc[i]['Twitter_Descr'])
        verified.append(df.iloc[i]['verified'])
        if (isWordPresent(s, word)):
            #print("Yes")
            #Number=Number+1 
            #print(Number)
            Actual_CEO.append('Yes')
        elif (isWordPresent(s,df.Company[i])):
            #print("Yes")
            #Number=Number+1
            #print(Number)
            Actual_CEO.append('Yes')           
        else :
            #print("No")
            #Number=Number+1
            #print(Number)
            Actual_CEO.append(np.NaN) 
    except :
        #print("No")
        #Number=Number+1
        Actual_CEO.append(np.NaN)
        pass

# %%
columns = ['CEO','Company', 'Handle', 'Twitter_Descr', 'verified','Actual_CEO']
tdf = pd.DataFrame(list(zip(ceos, companies, handles, descriptions, verified, Actual_CEO)), columns =columns) 
tdf.dropna(inplace=True)
tdf= tdf[tdf['verified']!=False]
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162 entries, 1 to 1287
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CEO            162 non-null    object
#  1   Company        162 non-null    object
#  2   Handle         162 non-null    object
#  3   Twitter_Descr  162 non-null    object
#  4   verified       162 non-null    bool
#  5   Actual_CEO     162 non-null    object
# dtypes: bool(1), object(5)
# memory usage: 7.8+ KB

# %%
tdf.to_csv(r"C:\Users\Anshu\Downloads\Outputfinal.csv", index=False)
