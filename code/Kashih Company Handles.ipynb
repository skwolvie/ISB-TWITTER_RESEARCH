# %%
import os
import pandas as pd

# %%
os.chdir('../kashish files/output')
os.listdir()
# Out:
# ['Company_Exhaustive_List.csv',
#  'Company_Tweepy_Verified.csv',
#  'Company_Twint_Verified.csv',
#  'Gsearch1.csv',
#  'Gsearch2.csv',
#  'Gsearch3.csv',
#  'Gsearch4.csv',
#  'Kashish_GoogleSearcher_CompanyHandles_verified.csv']

# %%
df= pd.read_csv('old/Company_Twint_Verified.csv')
df.shape
# Out:
# (387, 25)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (387, 25)

# %%
df= df[['GVKEY', 'Company', 'Company_Handles', 'bio', 'verified']]
df.dropna(subset=['Company_Handles'], inplace=True)
df
# Out:
#       GVKEY                       Company Company_Handles  \
# 0      1045   AMERICAN AIRLINES GROUP INC     americanair
# 1      1078           ABBOTT LABORATORIES    abbottglobal
# 2      1161        ADVANCED MICRO DEVICES             amd
# 3      1177                     AETNA INC           aetna
# 4      1209  AIR PRODUCTS & CHEMICALS INC     AirProducts
# ..      ...                           ...             ...
# 382   65345          AMERICAN CAPITAL LTD       abcapital
# 383  138205                  ILLUMINA INC        illumina
# 384  162448   ALPHA NATURAL RESOURCES INC     ONresources
# 385  174130                   EMBARQ CORP     centurylink
# 386  179621   PHILIP MORRIS INTERNATIONAL       InsidePMI
#
#                                                    bio  verified
# 0    Official Twitter for the world’s largest airli...      True
# 1    The @AbbottGlobal Twitter page was discontinue...      True
# 2    Official corporate news about the AMD technolo...      True
# 3                                                  NaN      True
# 4    Industry-leading company of 19,000+ dedicated ...      True
# ..                                                 ...       ...
# 382                 Protecting | Investing | Financing      True
# 383  Illumina is dedicated to advancing human healt...      True
# 384  Official account of Ontario’s Ministry of Natu...      True
# 385  Transforming lives and businesses through inno...      True
# 386  We’re designing a #smokefree future. Find out ...      True
#
# [387 rows x 5 columns]

# %%
df.dropna(subset=['name'], inplace=True)

# %%
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)

# %%
df.to_csv('Kashish_GoogleSearcher_CompanyHandles_verified.csv', index=False)

# %%
dff=pd.read_excel(r'../../input/SnP_500_CEO_Names.xlsx')
dff.dropna(inplace=True)
dff.drop(['CEO Name', 'YEAR'], axis=1, inplace=True)
dff.drop_duplicates(subset=['Company'], inplace=True)
dff.shape
# Out:
# (782, 3)

# %%
a=df.Company.tolist()

# %%
df1=dff[~dff.Company.isin(a)]

# %%
df1
# Out:
#                            Company   GVKEY  EXECID
# 0       ADC TELECOMMUNICATIONS INC    1013   10203
# 17      PINNACLE WEST CAPITAL CORP    1075   10739
# 56                       AETNA INC    1177   14660
# 93            ALLEGHENY ENERGY INC    1279    5899
# 110                    ALLTEL CORP    1318   12422
# ...                            ...     ...     ...
# 8598            CAPRI HOLDINGS LTD  198058   45334
# 8628     WELLCARE HEALTH PLANS INC  260778   31719
# 8640  LYONDELLBASELL INDUSTRIES NV  294524   31023
# 8651                  ALLEGION PLC  316056   34850
# 8658            NVENT ELECTRIC PLC  326688   49088
#
# [406 rows x 3 columns]

# %%
df1.to_csv('GSearch_failed_Handles.csv', index=False)

# %%
import tweepy
import pandas as pd
import numpy as np

# assign the values accordingly 
consumer_key = "OMJv2A5J1XvXdBSLykjbzQvjN" 
consumer_secret = "IF1tUCs5uFhKNN4PILugYgTdfaFDEakS4gbzWHKEL92dIoSRHA" 
access_token = "3097042092-HXzJwRZ4BRSiTa67RfHnlE7CeF01gutElIP6UoT" 
access_token_secret = "kZYcycMakp0z3jcGC07UpLynOWvvtoBiAmwVjJKziSYB8"

# authorization of consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
# set access to user's access key and access secret  
auth.set_access_token(access_token, access_token_secret) 
  
# calling the api  
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
from collections import Counter
cnt = Counter()
for text in df1["Company"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(30)
# Out:
# [('INC', 194),
#  ('CORP', 108),
#  ('CO', 35),
#  ('PLC', 21),
#  ('ENERGY', 19),
#  ('HOLDINGS', 17),
#  ('&', 17),
#  ('GROUP', 16),
#  ('TECHNOLOGIES', 10),
#  ('FINANCIAL', 9),
#  ('INTL', 9),
#  ('LTD', 8),
#  ('INDUSTRIES', 7),
#  ('RESOURCES', 7),
#  ('INTERNATIONAL', 6),
#  ('REALTY', 6),
#  ('HEALTH', 6),
#  ('BRANDS', 5),
#  ('SYSTEMS', 5),
#  ('CITY', 4),
#  ('COS', 4),
#  ('NATIONAL', 4),
#  ('TECHNOLOGY', 4),
#  ('UNITED', 4),
#  ('PROPERTY', 4),
#  ('SOLUTIONS', 3),
#  ('AMERICAN', 3),
#  ('MATERIALS', 3),
#  ('GLOBAL', 3),
#  ('SOUTHERN', 3)]

# %%
df=df1
df1.shape
# Out:
# (406, 3)

# %%
df['Company']= df['Company'].str.replace(r"\(.*\)","")
df['Company']= df['Company'].str.replace(' -CL A', '')
df['Company']= df['Company'].str.replace(' -CL B', '')
df['Company']= df['Company'].str.replace('/DE', '')
df['Company']= df['Company'].str.replace('/ME', '')
#df['Company']= df['Company'].str.replace(r'\([^()]*\)', '')
df['Company']= df['Company'].str.replace('ARCHER-DANIELS-MIDLAND CO', 'ARCHER-DANIELS-MIDLAND')
df['Company']= df['Company'].str.strip()
# Out:
# <ipython-input-35-918051c6f60a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace(r"\(.*\)","")
# <ipython-input-35-918051c6f60a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace(' -CL A', '')
# <ipython-input-35-918051c6f60a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace(' -CL B', '')
# <ipython-input-35-918051c6f60a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace('/DE', '')
# <ipython-input-35-918051c6f60a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace('/ME', '')
# <ipython-input-35-918051c6f60a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.replace('ARCHER-DANIELS-MIDLAND CO', 'ARCHER-DANIELS-MIDLAND')
# <ipython-input-35-918051c6f60a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df['Company'].str.strip()

# %%
cp=[]
for i in df.Company:
    a=i.split()
    if len(a)==6:
        i=i.replace(' CORP', '')
        cp.append(i)
        #print(i) 
    elif len(a)>=3:
        #i=i.join(content.split(' ')[:-1])
        i= i.replace(' INC', '')
        i= i.replace(' INTL', '')
        i= i.replace(' CORP', '')
        i= i.replace(' CO', '')
        i= i.replace(' COS', '')
        i= i.replace(' PLC', '')
        i= i.replace(' GRP', '')
        i= i.replace(' GROUP', '')
        
        i= i.replace(' SVCS', '')
        i= i.replace(' PLC', '')
        i= i.replace('\/.*$', '')
        cp.append(i)
    else:
        cp.append(i)
               
    
len(cp)
# Out:
# 406

# %%
df['Company']=cp
# Out:
# <ipython-input-37-9082fa34ac59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']=cp

# %%
df['Company'] = df['Company'].str.replace('-', ' ')
df['Company']= df.Company.str.strip()
# Out:
# <ipython-input-38-2da13a37bbbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company'] = df['Company'].str.replace('-', ' ')
# <ipython-input-38-2da13a37bbbd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company']= df.Company.str.strip()

# %%
tdf=pd.DataFrame()
companies=[]
gvk=[]
handles=[]
descriptions=[]
verified=[]

badnames=[]
badgv=[]

for i in range(len(df)):
    users = api.search_users(df.iloc[i]['Company'])                     
    lst=[]
    for user in users:
        lst.append(user.screen_name)
    if len(lst)==0:
        badnames.append(df.iloc[i]['Company'])
        badgv.append(df.iloc[i]['GVKEY'])
        print('--------------------------------- ',df.iloc[i]['Company'],'---------------------------------' )
    for j in lst:
        obj=api.get_user(j)
        result=obj.verified
        if result==True:
            companies.append(df.iloc[i]['Company'])
            gvk.append(df.iloc[i]['GVKEY'])
            handles.append(j)
            descriptions.append(obj.description)
            verified.append(result)
            print(df.iloc[i]['Company'], j)
# Out:
# ---------------------------------  ADC TELECOMMUNICATIONS ---------------------------------
# ---------------------------------  PINNACLE WEST CAPITAL ---------------------------------
# AETNA INC Aetna
# ---------------------------------  ALLTEL CORP ---------------------------------
# AMERICAN ELECTRIC POWER AEPnews
# ---------------------------------  NABORS INDUSTRIES LTD ---------------------------------
# APPLE INC Apple
# APPLE INC pschiller
# APPLE INC AngelaAhrendts
# APPLE INC BoysStateMovie
# APPLE INC trippmickle
# APPLE INC DaveAtBEATS
# ---------------------------------  ASHLAND GLOBAL HOLDINGS ---------------------------------
# SOUTHERN GAS SSGC_Official
# AUTOMATIC DATA PROCESSING ADP
# BAKER HUGHES Avitas_Systems
# CONSTELLATION ENERGY ConstellationEG
# BANK OF NEW YORK MELLON BNYMellon
# ---------------------------------  UNISYS CORP ---------------------------------
# ---------------------------------  CSX CORP ---------------------------------
# PROGRESS ENERGY EnergyCIO
# PROGRESS ENERGY Shell_US
# PROGRESS ENERGY mankofit
# PROGRESS ENERGY Exelon
# ---------------------------------  CIRCUIT CITY STORES ---------------------------------
# CA INC MarvelStudiosCA
# CA INC eBayCanada
# CA INC CAinc
# CA INC CA_IM
# COOPERS PwC
# COOPERS PwCUS
# COOPERS PwC_UK
# COOPERS coopers_craft
# COOPERS PwC_Nigeria
# COOPERS PwCTax
# COUNTRYWIDE FINANCIAL BankofAmerica
# COUNTRYWIDE FINANCIAL BofA_News
# COUNTRYWIDE FINANCIAL BofA_Tips
# DISNEY  CO WaltDisneyCo
# DISNEY  CO WDWToday
# DISNEY  CO DisneyPlusUK
# DISNEY  CO DisneyXDUK
# DISNEY  CO PixarSoul
# DISNEY  CO DisneyCareers
# DISNEY  CO DisneyGiftCard
# DISNEY  CO Disney_Insiders
# DISNEY  CO DisneyStudiosIE
# DISNEY  CO DisneyPlusHelp
# DISNEY  CO abigaildisney
# DISNEY  CO WDWGuestService
# DISNEY  CO hotstar_helps
# DOLLAR GENERAL DollarGeneral
# DU PONT  DE NEMOURS DuPont_News
# EATON eatoncorp
# EATON AshtonJEaton
# EATON AbbieEaton44
# EATON georgeeaton
# EATON MerEaton
# EATON btheiseneaton
# EATON BrandoEaton
# EATON joshua_eaton
# EATON LongEatonNorth
# EATON courtneyeaton
# EATON njerieaton
# EATON PaulDEaton52
# EATON CollinEatonHC
# ---------------------------------  EXPEDITORS WASH ---------------------------------
# ---------------------------------  FEDERAL NATIONAL MORTGA ASSN ---------------------------------
# ---------------------------------  FEDERAL REALTY INVESTMENT TR ---------------------------------
# ---------------------------------  FIRST HORIZON NATIONAL ---------------------------------
# FOREST LABORATORIES meury_bill
# GENUINE PARTS GMParts_ACDelco
# GENUINE PARTS NAPAKnowHow
# GENUINE PARTS baxiboilers
# ---------------------------------  WELLTOWER INC ---------------------------------
# ---------------------------------  HOLLYFRONTIER CORP ---------------------------------
# ---------------------------------  INTL BUSINESS MACHINES ---------------------------------
# ---------------------------------  INTL FLAVORS & FRAGRANCES ---------------------------------
# JACOBS ENGINEERING UCSDJacobs
# JACOBS ENGINEERING FredericJacobs
# SEARS HOLDINGS Sears
# KANSAS CITY SOUTHERN ATFKansasCity
# KANSAS CITY SOUTHERN ETeaparty25
# LEGG MASON CitiOpen
# JEFFERIES FINANCIAL HandlerRich
# L BRANDS LNforBrands
# L BRANDS l3pje
# L BRANDS LVMH
# L BRANDS MDLZ
# L BRANDS BATplc
# L BRANDS joeybrezinski
# RANGE RESOURCES SignifyUni
# ---------------------------------  MARSH & MCLENNANS ---------------------------------
# ---------------------------------  MARSHALL & ILSLEY ---------------------------------
# ---------------------------------  MASCO CORP ---------------------------------
# MCCORMICK & SierraNMcCormic
# MCCORMICK & McCormickCorp
# MCCORMICK & mccormickspices
# MCCORMICK & TyMcCormick
# MCCORMICK & McCormickJohn
# MCCORMICK & KathrynrMcc
# MCCORMICK & neil_mccormick
# MCCORMICK & cmccormick08
# MCCORMICK & sadogre
# MCCORMICK & emily_mcck
# MCCORMICK & HyattMcCormick
# MCCORMICK & McCormick4Chefs
# MCCORMICK & RichforGA
# ---------------------------------  MEDCO HEALTH SOLUTIONS ---------------------------------
# MERRILL LYNCH & MerrillLynch
# MERRILL LYNCH & SallieKrawcheck
# MERRILL LYNCH & MarshallM13
# ---------------------------------  MOLEX INC ---------------------------------
# MYLAN NV MylanNews
# NATIONAL CITY CityOfNatlCity
# NATIONAL CITY CityNational
# NATIONAL CITY OKCNM
# NATIONAL CITY NWSKansasCity
# NATIONAL CITY NACCHOalerts
# NATIONAL CITY NALC_National
# NATIONAL CITY OfficialClarets
# NATIONAL CITY BathCity_FC
# ---------------------------------  NICOR INC ---------------------------------
# XCEL ENERGY XcelEnergyCtr
# ---------------------------------  ONEOK INC ---------------------------------
# PPG INDUSTRIES PPG
# ---------------------------------  PACCAR INC ---------------------------------
# ---------------------------------  PARKER HANNIFIN CORP ---------------------------------
# ---------------------------------  PENTAIR PLC ---------------------------------
# APPLIED BIOSYSTEMS thermofisher
# RAYMOND JAMES FINANCIAL RaymondJames
# RAYMOND JAMES FINANCIAL JustinWTSP
# AUTONATION INC CEOMikeJackson
# ---------------------------------  ROHM AND HAAS ---------------------------------
# ---------------------------------  ROWANMPANIES ---------------------------------
# ---------------------------------  SAFECO CORP ---------------------------------
# ---------------------------------  SCANA CORP ---------------------------------
# SCHERING PLOUGH Merck
# SMITH OfficialWillow
# SMITH RogerCraigSmith
# SMITH bastilledan
# SMITH ThatKevinSmith
# SMITH EmmittSmith22
# SMITH jaden
# SMITH TheJetOnTNT
# SMITH SenTinaSmith
# SMITH TheRealJRSmith
# SMITH TeamJuJu
# SMITH BradSmi
# SMITH BrianJacobSmith
# SMITH ememess
# SMITH BustaRhymes
# SMITH aetiology
# SMITH BradleySmith38
# SMITH michaelwsmith
# SMITH TorreySmithWR
# SMITH SenHydeSmith
# ---------------------------------  TEMPLE INLAND INC ---------------------------------
# ---------------------------------  TERADYNE INC ---------------------------------
# ---------------------------------  ENERGY FUTURE HOLDINGS ---------------------------------
# GLOBE LIFE GlobeLifeField
# GLOBE LIFE TIME
# GLOBE LIFE TEXPAMAN
# TYCO INTERNATIONAL johnsoncontrols
# UNITED PARCEL SERVICE UPS
# UNIVERSAL HEALTH CHGlobalHealth
# UNIVERSAL HEALTH WHOMalaysia
# ---------------------------------  VORNADO REALTY TRUST ---------------------------------
# WENDY'S INTERNATIONAL Wendys
# WENDY'S INTERNATIONAL CaitlinSinett
# ---------------------------------  MEADWESTVACO CORP ---------------------------------
# ---------------------------------  WEYERHAEUSER CO ---------------------------------
# WEC ENERGY aBayraktar1
# ---------------------------------  INTEGRYS HOLDING ---------------------------------
# ---------------------------------  ZIONS BANCORPORATION NA ---------------------------------
# ---------------------------------  BEAR STEARNSMPANIES ---------------------------------
# TRUIST FINANCIAL TruistNews
# NOBLE NobleGG
# NOBLE realrossnoble
# NOBLE BNBuzz
# NOBLE safiyanoble
# NOBLE nookBN
# NOBLE Noble16Mark
# NOBLE YOUNG_NOBLE1
# NOBLE ukinromania
# NOBLE BeNobleSchools
# NOBLE Nobsdaslushhkid
# NOBLE kezia_noble
# ---------------------------------  EMC CORP/MA ---------------------------------
# SUN MICROSYSTEMS Oracle
# SUN MICROSYSTEMS alpresnell
# SUN MICROSYSTEMS OracleANZ
# SUN MICROSYSTEMS Oracle_CH
# SUN MICROSYSTEMS larryellison
# ---------------------------------  GENZYME CORP ---------------------------------
# ---------------------------------  AIRGAS INC ---------------------------------
# JOY GLOBAL VDay
# SYNOVUS FINANCIAL synovus
# ---------------------------------  HEALTHPEAK PROPERTIES ---------------------------------
# ---------------------------------  PROGRESSIVE CORP OHIO ---------------------------------
# ---------------------------------  BARR PHARMACEUTICALS ---------------------------------
# ---------------------------------  CARNIVALORATION & ---------------------------------
# ---------------------------------  ZOETIS INC ---------------------------------
# ---------------------------------  MAXIM INTEGRATED PRODUCTS ---------------------------------
# ---------------------------------  ALTERA CORP ---------------------------------
# CINCINNATI FINANCIAL CincyTennis
# CINCINNATI FINANCIAL UnitedWayGC
# ---------------------------------  LABORATORY CP OF AMER HLDGS ---------------------------------
# ALLERGAN INC meury_bill
# WASHINGTON MUTUAL indiviglio
# ---------------------------------  PEOPLE'S UNITED FINL ---------------------------------
# ---------------------------------  COMMERCE BANCORP/NJ ---------------------------------
# SVB FINANCIAL SVB_Financial
# SVB FINANCIAL SVB_UK
# SVB FINANCIAL KateDMitchell
# SVB FINANCIAL dkimerling
# ---------------------------------  SANTANDER HOLDINGS USA ---------------------------------
# ---------------------------------  IQVIA HOLDINGS ---------------------------------
# ---------------------------------  MALLINCKRODT PLC ---------------------------------
# TWITTER INC Twitter
# TWITTER INC TwitterData
# TWITTER INC WWE
# TWITTER INC SEGA
# TWITTER INC INCIndia
# TWITTER INC amazon
# TWITTER INC acnnews
# TWITTER INC GoPro
# TWITTER INC WWEUniverse
# TWITTER INC MarvelMusicInc
# TWITTER INC MarvelUK
# TWITTER INC amazonIN
# TWITTER INC CanonUSA
# TWITTER INC ASUS
# TWITTER INC Stussy
# TWITTER INC InterFM897
# TWITTER INC gmanetwork
# TWITTER INC HondaCanada
# TWITTER INC ANSYS
# ---------------------------------  DENBURY RESOURCES ---------------------------------
# ---------------------------------  ALLIED WASTE INDUSTRIES ---------------------------------
# ---------------------------------  BAXALTA INC ---------------------------------
# ---------------------------------  PMC SIERRA INC ---------------------------------
# ---------------------------------  CEPHALON INC ---------------------------------
# UNITED STATES STEEL dennisogbe
# JONES OwenJones84
# JONES KySportsRadio
# JONES actordougjones
# JONES ManMadeMoon
# JONES MotherJones
# JONES Lesdoggg
# JONES DowJones
# JONES JonnyBones
# JONES luciejones1
# JONES Nas
# JONES RealCJ10
# JONES RealSirTomJones
# JONES themiltonjones
# JONES curtisjr_10
# JONES VinnieJones65
# JONES Byron31Jump
# JONES JessicaJones
# JONES theferocity
# ---------------------------------  AMBAC FINANCIAL ---------------------------------
# MONSTER BEVERAGE MonsterEnergy
# XL LTD qikipedia
# ---------------------------------  MGIC INVESTMENT/WI ---------------------------------
# PAYPAL HOLDINGS PayPal
# PAYPAL HOLDINGS PayPalUK
# PERRIGO billyperrigo
# ---------------------------------  ROPER TECHNOLOGIES ---------------------------------
# SYNOPSYS INC SW_Integrity
# ---------------------------------  KOHL'S CORP ---------------------------------
# ---------------------------------  COMPUWARE CORP ---------------------------------
# ---------------------------------  FOURRNERS PROPERTY TR ---------------------------------
# ---------------------------------  INGEVITY CORP ---------------------------------
# ALLERGAN PLC brentlsaunders
# ALLERGAN PLC meury_bill
# ---------------------------------  ADVANSIX INC ---------------------------------
# FOSSIL Fossil
# FOSSIL fossilenergygov
# FOSSIL JDFossilBedsNPS
# FOSSIL FlorissantNPS
# ---------------------------------  BROOKFIELD PROPERTY REIT ---------------------------------
# ---------------------------------  LAMB WESTON HOLDINGS ---------------------------------
# ---------------------------------  INCYTE CORP ---------------------------------
# SIMON PROPERTY _simonlambert
# ---------------------------------  MID AMERICA APT CMNTYS ---------------------------------
# ---------------------------------  QLOGIC CORP ---------------------------------
# ---------------------------------  BIOVERATIV INC ---------------------------------
# ---------------------------------  WESTROCK CO ---------------------------------
# ---------------------------------  AVALONBAYMMUNITIES ---------------------------------
# ---------------------------------  AK STEEL HOLDING ---------------------------------
# ---------------------------------  PROLOGIS INC ---------------------------------
# ---------------------------------  LEHMAN BROTHERS HOLDINGS ---------------------------------
# ---------------------------------  APARTMENT INVST & MGMT ---------------------------------
# ---------------------------------  AFFILIATEDMPUTER SERVICES ---------------------------------
# ---------------------------------  REALTYOME ---------------------------------
# ---------------------------------  TECHNIPFMC PLC ---------------------------------
# APOLLO EDUCATION ApolloTheater
# BAKER HUGHES Avitas_Systems
# ---------------------------------  JBG SMITH PPTYS ---------------------------------
# DOW INC DowNewsroom
# DOW INC DowPackaging
# DOW INC DuPont_News
# CAMERON INTERNATIONAL cameron_tiff
# DISH NETWORK dish_answers
# DISH NETWORK CBSSportsNet
# DISH NETWORK carriesheffield
# DISH NETWORK freespeechtv
# DISH NETWORK DishMx
# ---------------------------------  SUNEDISON INC ---------------------------------
# ---------------------------------  EVEREST RE LTD ---------------------------------
# ---------------------------------  DIAMOND OFFSHRE DRILLING ---------------------------------
# ---------------------------------  QWESTMMUNICATION ---------------------------------
# ALTABA INC Yahoo
# ALTABA INC YahooSG
# DEAN FOODS TysonFoodsCEO
# ABERCROMBIE & FITCH Abercrombie
# ABERCROMBIE & FITCH AbercrombieHelp
# ABERCROMBIE & FITCH abercrombiekids
# ENDO INTERNATIONAL TheLancetEndo
# ---------------------------------  IMS HEALTH HOLDINGS ---------------------------------
# ---------------------------------  CIENA CORP ---------------------------------
# ---------------------------------  ALEXANDRIA R E EQUITIES ---------------------------------
# BOSTON PROPERTIES PeterSouhleris
# UNITED RENTALS UnitedRentals
# ---------------------------------  AMCOR PLC ---------------------------------
# NIELSEN HOLDINGS nielsen
# ---------------------------------  CNX RESOURCESORATION ---------------------------------
# REYNOLDS AMERICAN coreyreynoldsLA
# ---------------------------------  SBAMMUNICATIONS ---------------------------------
# ---------------------------------  HUDSON CITY BANCORP ---------------------------------
# AGILENT TECHNOLOGIES AgilentChem
# TAPESTRY INC Coach
# GLOBAL PAYMENTS VisaNews
# GLOBAL PAYMENTS DiscoverGlobal
# GLOBAL PAYMENTS Blackhawk
# WILLIS TOWERS WATSON WTWesp
# ---------------------------------  CENTENE CORP ---------------------------------
# ---------------------------------  TRANSDIGM ---------------------------------
# CIT Canberra_CIT
# CIT CitImmCanada
# CIT FedCitSci
# CIT MCNocando
# CIT CitAdviceScot
# CIT IMA_CitRights
# CIT NatCitAlliance
# CIT CitSciBio
# ---------------------------------  QEP RESOURCES ---------------------------------
# ---------------------------------  ASSURANT INC ---------------------------------
# ---------------------------------  MARKETAXESS HOLDINGS ---------------------------------
# ---------------------------------  HOSPIRA INC ---------------------------------
# ---------------------------------  METROPCSMMUNICATIONS ---------------------------------
# MOSAIC CO SuttonBStracke
# ---------------------------------  CF INDUSTRIES HOLDINGS ---------------------------------
# ---------------------------------  LEIDOS HOLDINGS ---------------------------------
# NYSE EURONEXT artmarketdotcom
# NYSE EURONEXT nokia
# ---------------------------------  DIAMONDBACK ENERGY ---------------------------------
# WINDSTREAM HOLDINGS Windstream
# TIME WARNER CABLE SpectrumSN
# TIME WARNER CABLE SportsNetLA
# TIME WARNER CABLE Mike_Bresnahan
# TIME WARNER CABLE spectrumcenter
# ---------------------------------  BROADRIDGE FINANCIAL SOLUTNS ---------------------------------
# ---------------------------------  COVIDIEN PLC ---------------------------------
# ---------------------------------  CAREFUSION CORP ---------------------------------
# ---------------------------------  FLEETCOR TECHNOLOGIES ---------------------------------
# ---------------------------------  MOTOROLA MOBILITY HLDGS ---------------------------------
# ---------------------------------  HUNTINGTON INGALLS IND ---------------------------------
# ---------------------------------  WPX ENERGY ---------------------------------
# ---------------------------------  FORTUNE BRANDS HOME & SECUR ---------------------------------
# ---------------------------------  CAPRI HOLDINGS LTD ---------------------------------
# ---------------------------------  LYONDELLBASELL INDUSTRIES NV ---------------------------------

# %%
len(badnames)
# Out:
# 115

# %%
columns = ['GVKEY', 'Company', 'Company_Handles', 'bio', 'verified']
tdf = pd.DataFrame(list(zip(gvk, companies, handles, descriptions, verified)), columns =columns) 
tdf.dropna(inplace=True)
tdf= tdf[tdf['verified']!=False]
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259 entries, 0 to 258
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   GVKEY            259 non-null    int64
#  1   Company          259 non-null    object
#  2   Company_Handles  259 non-null    object
#  3   bio              259 non-null    object
#  4   verified         259 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 10.4+ KB

# %%
dfs
# Out:
#       GVKEY                    Company  Company_Handles  \
# 0      1177                  AETNA INC            Aetna
# 1      1440    AMERICAN ELECTRIC POWER          AEPnews
# 8      1837               SOUTHERN GAS    SSGC_Official
# 9      1891  AUTOMATIC DATA PROCESSING              ADP
# 11     1995       CONSTELLATION ENERGY  ConstellationEG
# 12     2019    BANK OF NEW YORK MELLON        BNYMellon
# 43     4016             DOLLAR GENERAL    DollarGeneral
# 44     4087        DU PONT  DE NEMOURS      DuPont_News
# 58     4843        FOREST LABORATORIES       meury_bill
# 64     6307             SEARS HOLDINGS            Sears
# 67     6653                 LEGG MASON         CitiOpen
# 68     6682        JEFFERIES FINANCIAL      HandlerRich
# 75     6788            RANGE RESOURCES       SignifyUni
# 92     7637                   MYLAN NV        MylanNews
# 101    7977                XCEL ENERGY    XcelEnergyCtr
# 102    8247             PPG INDUSTRIES              PPG
# 103    8488         APPLIED BIOSYSTEMS     thermofisher
# 106    9063             AUTONATION INC   CEOMikeJackson
# 107    9459            SCHERING PLOUGH            Merck
# 130   10787         TYCO INTERNATIONAL  johnsoncontrols
# 131   10920      UNITED PARCEL SERVICE              UPS
# 136   11550                 WEC ENERGY      aBayraktar1
# 137   11856           TRUIST FINANCIAL       TruistNews
# 154   13003                 JOY GLOBAL             VDay
# 155   13041          SYNOVUS FINANCIAL          synovus
# 158   15708               ALLERGAN INC       meury_bill
# 159   16243          WASHINGTON MUTUAL       indiviglio
# 183   23978        UNITED STATES STEEL       dennisogbe
# 202   24316           MONSTER BEVERAGE    MonsterEnergy
# 203   24318                     XL LTD        qikipedia
# 206   24782                    PERRIGO     billyperrigo
# 207   24975               SYNOPSYS INC     SW_Integrity
# 214   29389             SIMON PROPERTY    _simonlambert
# 215   31122           APOLLO EDUCATION    ApolloTheater
# 220   60894      CAMERON INTERNATIONAL     cameron_tiff
# 228   62655                 DEAN FOODS    TysonFoodsCEO
# 232   63645         ENDO INTERNATIONAL    TheLancetEndo
# 233   64925          BOSTON PROPERTIES   PeterSouhleris
# 234   66065             UNITED RENTALS    UnitedRentals
# 235  100873           NIELSEN HOLDINGS          nielsen
# 236  120877          REYNOLDS AMERICAN  coreyreynoldsLA
# 237  126554       AGILENT TECHNOLOGIES      AgilentChem
# 238  140541               TAPESTRY INC            Coach
# 242  144009       WILLIS TOWERS WATSON           WTWesp
# 251  162129                  MOSAIC CO   SuttonBStracke
# 254  174490        WINDSTREAM HOLDINGS       Windstream
#
#                                                    bio  verified
# 0    Every day, as part of @CVSHealth, we join you ...      True
# 1    The Official AEP account for latest news, info...      True
# 8    Sui Southern Gas Company is Pakistan's leading...      True
# 9    HR, Talent, Time Management, Benefits and Payr...      True
# 11   Constellation, an Exelon company, is a leading...      True
# 12   BNY Mellon delivers informed investment manage...      True
# 43   With 17,000 stores, we’re here to Serve Others...      True
# 44   For over 200 years DuPont has been innovating ...      True
# 58                  Chief Commercial Officer @allergan      True
# 64   making moments matter™. The big, the little, t...      True
# 67   🎾 ATP 500 & WTA International Series Tournamen...      True
# 68   CEO Jefferies Financial Group/Board Chair U of...      True
# 75   Brighter by the day! Signify Lighting Academy ...      True
# 92   We have combined with Upjohn, formerly a divis...      True
# 101  America’s most intimate arena. Home of the @mn...      True
# 102  A global innovator in paints, coatings and mat...      True
# 103  Thermo Fisher Scientific Inc. is the world lea...      True
# 106     Executive Chairman and CEO of AutoNation, Inc.      True
# 107  We have always been and always will be inventi...      True
# 130  105,000 experts globally, dedicated to protect...      True
# 131  Stay connected to global trade & logistics. Tw...      True
# 136  Bakan Yardımcısı, Enerji ve Tabii Kaynaklar Ba...      True
# 137  @BBT and @SunTrust have joined to become Truis...      True
# 154  Global Activist Movement to End Violence Again...      True
# 155  Synovus (NYSE:SNV) provides retail and commerc...      True
# 158                 Chief Commercial Officer @allergan      True
# 159  Former Reuters Breakingviews Washington column...      True
# 183  Man of Steel with Heart of Gold and Survivor o...      True
# 202  #UnleashTheBeast\nhttps://t.co/qgChRebwPI\nhtt...      True
# 203  A Quite Interesting Twitter feed from the team...      True
# 206   Reporter @TIME. DM me for secure contact details      True
# 207  The official Twitter account for @Synopsys Sof...      True
# 214  This is Money Editor and in charge of MailOnli...      True
# 215  The Soul of American Culture • President & CEO...      True
# 220                            Artistic Director, TIFF      True
# 228            #RaisingExpectations\n#TysonCommunities      True
# 232  Your leading source of international, cutting-...      True
# 233  Love buying and rehabbing properties....Archit...      True
# 234  The official Twitter account for United Rental...      True
# 235     Helping the world understand media insights. 📺      True
# 236  Actor/Writer/Producer-Resident Alien🤠-All-Amer...      True
# 237  Agilent's Chemical Analysis Group offers lab &...      True
# 238            The original American house of leather.      True
# 242  Tú ves el futuro. Nosotros te ayudamos a llega...      True
# 251  Mom of 3. Art & fashion lover. Official Cast m...      True
# 254  Windstream is an innovative communications & s...      True

# %%
dfs.columns=['GVKEY', 'Company', 'Handle', 'Twitter_Descr', 'verified']
dfs
# Out:
#       GVKEY                    Company           Handle  \
# 0      1177                  AETNA INC            Aetna
# 1      1440    AMERICAN ELECTRIC POWER          AEPnews
# 8      1837               SOUTHERN GAS    SSGC_Official
# 9      1891  AUTOMATIC DATA PROCESSING              ADP
# 11     1995       CONSTELLATION ENERGY  ConstellationEG
# 12     2019    BANK OF NEW YORK MELLON        BNYMellon
# 43     4016             DOLLAR GENERAL    DollarGeneral
# 44     4087        DU PONT  DE NEMOURS      DuPont_News
# 58     4843        FOREST LABORATORIES       meury_bill
# 64     6307             SEARS HOLDINGS            Sears
# 67     6653                 LEGG MASON         CitiOpen
# 68     6682        JEFFERIES FINANCIAL      HandlerRich
# 75     6788            RANGE RESOURCES       SignifyUni
# 92     7637                   MYLAN NV        MylanNews
# 101    7977                XCEL ENERGY    XcelEnergyCtr
# 102    8247             PPG INDUSTRIES              PPG
# 103    8488         APPLIED BIOSYSTEMS     thermofisher
# 106    9063             AUTONATION INC   CEOMikeJackson
# 107    9459            SCHERING PLOUGH            Merck
# 130   10787         TYCO INTERNATIONAL  johnsoncontrols
# 131   10920      UNITED PARCEL SERVICE              UPS
# 136   11550                 WEC ENERGY      aBayraktar1
# 137   11856           TRUIST FINANCIAL       TruistNews
# 154   13003                 JOY GLOBAL             VDay
# 155   13041          SYNOVUS FINANCIAL          synovus
# 158   15708               ALLERGAN INC       meury_bill
# 159   16243          WASHINGTON MUTUAL       indiviglio
# 183   23978        UNITED STATES STEEL       dennisogbe
# 202   24316           MONSTER BEVERAGE    MonsterEnergy
# 203   24318                     XL LTD        qikipedia
# 206   24782                    PERRIGO     billyperrigo
# 207   24975               SYNOPSYS INC     SW_Integrity
# 214   29389             SIMON PROPERTY    _simonlambert
# 215   31122           APOLLO EDUCATION    ApolloTheater
# 220   60894      CAMERON INTERNATIONAL     cameron_tiff
# 228   62655                 DEAN FOODS    TysonFoodsCEO
# 232   63645         ENDO INTERNATIONAL    TheLancetEndo
# 233   64925          BOSTON PROPERTIES   PeterSouhleris
# 234   66065             UNITED RENTALS    UnitedRentals
# 235  100873           NIELSEN HOLDINGS          nielsen
# 236  120877          REYNOLDS AMERICAN  coreyreynoldsLA
# 237  126554       AGILENT TECHNOLOGIES      AgilentChem
# 238  140541               TAPESTRY INC            Coach
# 242  144009       WILLIS TOWERS WATSON           WTWesp
# 251  162129                  MOSAIC CO   SuttonBStracke
# 254  174490        WINDSTREAM HOLDINGS       Windstream
#
#                                          Twitter_Descr  verified
# 0    Every day, as part of @CVSHealth, we join you ...      True
# 1    The Official AEP account for latest news, info...      True
# 8    Sui Southern Gas Company is Pakistan's leading...      True
# 9    HR, Talent, Time Management, Benefits and Payr...      True
# 11   Constellation, an Exelon company, is a leading...      True
# 12   BNY Mellon delivers informed investment manage...      True
# 43   With 17,000 stores, we’re here to Serve Others...      True
# 44   For over 200 years DuPont has been innovating ...      True
# 58                  Chief Commercial Officer @allergan      True
# 64   making moments matter™. The big, the little, t...      True
# 67   🎾 ATP 500 & WTA International Series Tournamen...      True
# 68   CEO Jefferies Financial Group/Board Chair U of...      True
# 75   Brighter by the day! Signify Lighting Academy ...      True
# 92   We have combined with Upjohn, formerly a divis...      True
# 101  America’s most intimate arena. Home of the @mn...      True
# 102  A global innovator in paints, coatings and mat...      True
# 103  Thermo Fisher Scientific Inc. is the world lea...      True
# 106     Executive Chairman and CEO of AutoNation, Inc.      True
# 107  We have always been and always will be inventi...      True
# 130  105,000 experts globally, dedicated to protect...      True
# 131  Stay connected to global trade & logistics. Tw...      True
# 136  Bakan Yardımcısı, Enerji ve Tabii Kaynaklar Ba...      True
# 137  @BBT and @SunTrust have joined to become Truis...      True
# 154  Global Activist Movement to End Violence Again...      True
# 155  Synovus (NYSE:SNV) provides retail and commerc...      True
# 158                 Chief Commercial Officer @allergan      True
# 159  Former Reuters Breakingviews Washington column...      True
# 183  Man of Steel with Heart of Gold and Survivor o...      True
# 202  #UnleashTheBeast\nhttps://t.co/qgChRebwPI\nhtt...      True
# 203  A Quite Interesting Twitter feed from the team...      True
# 206   Reporter @TIME. DM me for secure contact details      True
# 207  The official Twitter account for @Synopsys Sof...      True
# 214  This is Money Editor and in charge of MailOnli...      True
# 215  The Soul of American Culture • President & CEO...      True
# 220                            Artistic Director, TIFF      True
# 228            #RaisingExpectations\n#TysonCommunities      True
# 232  Your leading source of international, cutting-...      True
# 233  Love buying and rehabbing properties....Archit...      True
# 234  The official Twitter account for United Rental...      True
# 235     Helping the world understand media insights. 📺      True
# 236  Actor/Writer/Producer-Resident Alien🤠-All-Amer...      True
# 237  Agilent's Chemical Analysis Group offers lab &...      True
# 238            The original American house of leather.      True
# 242  Tú ves el futuro. Nosotros te ayudamos a llega...      True
# 251  Mom of 3. Art & fashion lover. Official Cast m...      True
# 254  Windstream is an innovative communications & s...      True

# %%
dfs.to_csv(r"D:\OneDrive - Indian School of Business\Projects\Mindset\tweets\TWITTERHANDLESSEARCH\output\verified\Company\tweepy_verified_single_company_handles_2.csv", index=False)

# %%
len(dfs)
# Out:
# 46
