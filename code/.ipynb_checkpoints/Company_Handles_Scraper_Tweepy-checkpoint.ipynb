# %% [markdown]
# # Tweepy Handles Scraper

# %% [markdown]
# ## INIT

# %%
import tweepy
import pandas as pd
import numpy as np

# %%
# assign the values accordingly 
consumer_key = "4UK25l7CHvfv47CmvWtrSGBYW" 
consumer_secret = "WUO6GHT5NW506qqa3lSt1F836kWHXUf2sM5EjwFcWU1nStwGVT" 
access_token = "3097042092-7Kxie8uQDEYfS0BGNYoc93i2oRHrSW4toeibhU4" 
access_token_secret = "rCBPLXlTEzjX4J6X0pSrOHAcs85iP9zJiEXGXrCDwYajo"

# %%
# authorization of consumer key and consumer secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
  
# set access to user's access key and access secret  
auth.set_access_token(access_token, access_token_secret) 
  
# calling the api  
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
df=pd.read_excel(r'../input/SnP_500_CEO_Names.xlsx')
df.dropna(inplace=True)
df.drop(['CEO Name', 'YEAR'], axis=1, inplace=True)
df.drop_duplicates(subset=['Company'], inplace=True)
df.shape
#df['ceos']= df[['CEO Name', 'Company']].apply(lambda x: ' '.join(x), axis=1)
#df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.shape
# Out:
# (782, 3)

# %%
df.columns
# Out:
# Index(['Company', 'GVKEY', 'EXECID'], dtype='object')

# %%
df.head()
# Out:
#                         Company  GVKEY  EXECID
# 0    ADC TELECOMMUNICATIONS INC   1013   10203
# 4   AMERICAN AIRLINES GROUP INC   1045   14591
# 17   PINNACLE WEST CAPITAL CORP   1075   10739
# 30          ABBOTT LABORATORIES   1078   14300
# 43       ADVANCED MICRO DEVICES   1161   20918

# %%
from collections import Counter
cnt = Counter()
for text in df["Company"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(30)
# Out:
# [('INC', 384),
#  ('CORP', 193),
#  ('CO', 78),
#  ('&', 35),
#  ('GROUP', 32),
#  ('ENERGY', 30),
#  ('PLC', 30),
#  ('HOLDINGS', 23),
#  ('FINANCIAL', 21),
#  ('LTD', 15),
#  ('TECHNOLOGIES', 14),
#  ('INTERNATIONAL', 13),
#  ('INTL', 13),
#  ('COS', 10),
#  ('BRANDS', 9),
#  ('-CL', 9),
#  ('RESOURCES', 9),
#  ('AMERICAN', 8),
#  ('HEALTH', 8),
#  ('TECHNOLOGY', 8),
#  ('A', 8),
#  ('SYSTEMS', 8),
#  ('INDUSTRIES', 7),
#  ('COMMUNICATIONS', 7),
#  ('NATIONAL', 7),
#  ('REALTY', 7),
#  ('GLOBAL', 6),
#  ('SERVICES', 6),
#  ('SOLUTIONS', 5),
#  ('GRP', 5)]

# %%
df['CompanyName']= df['Company']

# %%
df['Company']= df['Company'].str.replace(r"\(.*\)","")
df['Company']= df['Company'].str.replace(' -CL A', '')
df['Company']= df['Company'].str.replace(' -CL B', '')
df['Company']= df['Company'].str.replace('/DE', '')
df['Company']= df['Company'].str.replace('/ME', '')
#df['Company']= df['Company'].str.replace(r'\([^()]*\)', '')
df['Company']= df['Company'].str.replace('ARCHER-DANIELS-MIDLAND CO', 'ARCHER-DANIELS-MIDLAND')
df['Company']= df['Company'].str.strip()

# %%
cp=[]
for i in df.Company:
    a=i.split()
    if len(a)==6:
        i=i.replace(' CORP', '')
        cp.append(i)
        #print(i) 
    elif len(a)>=3:
        #i=i.join(content.split(' ')[:-1])
        i= i.replace(' INC', '')
        i= i.replace(' INTL', '')
        i= i.replace(' CORP', '')
        i= i.replace(' CO', '')
        i= i.replace(' COS', '')
        i= i.replace(' PLC', '')
        i= i.replace(' GRP', '')
        i= i.replace(' GROUP', '')
        
        i= i.replace(' SVCS', '')
        i= i.replace(' PLC', '')
        i= i.replace('\/.*$', '')
        cp.append(i)
    else:
        cp.append(i)
               
    
len(cp)
# Out:
# 782

# %%
df['Company'].tolist()
# Out:
# ['ADC TELECOMMUNICATIONS INC',
#  'AMERICAN AIRLINES GROUP INC',
#  'PINNACLE WEST CAPITAL CORP',
#  'ABBOTT LABORATORIES',
#  'ADVANCED MICRO DEVICES',
#  'AETNA INC',
#  'AIR PRODUCTS & CHEMICALS INC',
#  'ALASKA AIR GROUP INC',
#  'ALLEGHENY ENERGY INC',
#  'HONEYWELL INTERNATIONAL INC',
#  'ALLTEL CORP',
#  'SKYWORKS SOLUTIONS INC',
#  'ALCOA INC',
#  'HESS CORP',
#  'BEAM INC',
#  'AMERICAN ELECTRIC POWER CO',
#  'AMERICAN EXPRESS CO',
#  'AFLAC INC',
#  'WYETH',
#  'AMERICAN INTERNATIONAL GROUP',
#  'TRANE INC',
#  'AMETEK INC',
#  'AMGEN INC',
#  'ANALOG DEVICES',
#  'NABORS INDUSTRIES LTD',
#  'ANHEUSER-BUSCH COS INC',
#  'APACHE CORP',
#  'APPLE INC',
#  'APPLIED MATERIALS INC',
#  'ARCHER-DANIELS-MIDLAND',
#  'ASHLAND GLOBAL HOLDINGS INC',
#  'SOUTHERN CO GAS',
#  'AUTODESK INC',
#  'AUTOMATIC DATA PROCESSING',
#  'AVERY DENNISON CORP',
#  'AVON PRODUCTS',
#  'BAKER HUGHES INC',
#  'BALL CORP',
#  'CONSTELLATION ENERGY GRP INC',
#  'BANK OF NEW YORK MELLON CORP',
#  'BARD  INC',
#  'BAXTER INTERNATIONAL INC',
#  'BECTON DICKINSON & CO',
#  'VERIZON COMMUNICATIONS INC',
#  'BEMIS CO INC',
#  'BERKSHIRE HATHAWAY',
#  'BEST BUY CO INC',
#  'BIOMET INC',
#  'BLACK & DECKER CORP',
#  'BLOCK H & R INC',
#  'VALARIS PLC',
#  'BOEING CO',
#  'OFFICEMAX INC',
#  'ROBERT HALF INTL INC',
#  'BRISTOL-MYERS SQUIBB CO',
#  'BROWN FORMAN CORP',
#  'BRUNSWICK CORP',
#  'BURLINGTON NORTHERN SANTA FE',
#  'UNISYS CORP',
#  'CIGNA CORP',
#  'CSX CORP',
#  'CAMPBELL SOUP CO',
#  'CONSTELLATION BRANDS',
#  'CARDINAL HEALTH INC',
#  'PROGRESS ENERGY INC',
#  'CATERPILLAR INC',
#  'CENTEX CORP',
#  'CENTURYLINK INC',
#  'JPMORGAN CHASE & CO',
#  'CHEVRON CORP',
#  'CHUBB CORP',
#  'CHURCH & DWIGHT INC',
#  'CIRCUIT CITY STORES INC',
#  'CINTAS CORP',
#  'IHEARTMEDIA INC',
#  'CLEVELAND-CLIFFS INC',
#  'CLOROX CO',
#  'COCA-COLA CO',
#  'COLGATE-PALMOLIVE CO',
#  'AON PLC',
#  'COMCAST CORP',
#  'COMERICA INC',
#  'CITIGROUP INC',
#  'CA INC',
#  'DXC TECHNOLOGY CO',
#  'CONAGRA BRANDS INC',
#  'CONSOLIDATED EDISON INC',
#  'CMS ENERGY CORP',
#  'COOPER INDUSTRIES PLC',
#  'COOPER COS INC',
#  'MOLSON COORS BEVERAGE CO',
#  'CORNING INC',
#  'COUNTRYWIDE FINANCIAL CORP',
#  'CUMMINS INC',
#  'DANAHER CORP',
#  'TARGET CORP',
#  'DEERE & CO',
#  'DELTA AIR LINES INC',
#  'DTE ENERGY CO',
#  'ADTALEM GLOBAL EDUCATION INC',
#  'DILLARDS INC',
#  'DISNEY  CO',
#  'DOLLAR GENERAL CORP',
#  'DOMINION ENERGY INC',
#  'DONNELLEY  & SONS CO',
#  'DOVER CORP',
#  'DUPONT DE NEMOURS INC',
#  'OMNICOM GROUP',
#  'DU PONT  DE NEMOURS',
#  'DUKE ENERGY CORP',
#  'DUN & BRADSTREET CORP',
#  'FLOWSERVE CORP',
#  'PERKINELMER INC',
#  'EASTMAN KODAK CO',
#  'EATON CORP PLC',
#  'ECOLAB INC',
#  'EL PASO CORP',
#  'EMERSON ELECTRIC CO',
#  'WEATHERFORD INTL PLC',
#  'ATMOS ENERGY CORP',
#  'EQUIFAX INC',
#  'EQT CORP',
#  'EXPEDITORS INTL WASH INC',
#  'EXXON MOBIL CORP',
#  'FMC CORP',
#  'NEXTERA ENERGY INC',
#  'FAMILY DOLLAR STORES',
#  'FEDEX CORP',
#  'FEDERAL NATIONAL MORTGA ASSN',
#  'FEDERAL REALTY INVESTMENT TR',
#  "MACY'S INC",
#  'FIFTH THIRD BANCORP',
#  'REGIONS FINANCIAL CORP',
#  'M & T BANK CORP',
#  'U S BANCORP',
#  'FIRST HORIZON NATIONAL CORP',
#  'WACHOVIA CORP',
#  'FLUOR CORP',
#  'FORD MOTOR CO',
#  'FOREST LABORATORIES',
#  'FRANKLIN RESOURCES INC',
#  'ARTHUR J GALLAGHER & CO',
#  'TEGNA INC',
#  'GAP INC',
#  'GENERAL DYNAMICS CORP',
#  'GENERAL ELECTRIC CO',
#  'GENERAL MILLS INC',
#  'GENERAL MOTORS CO',
#  'ELECTRONIC DATA SYSTEMS CORP',
#  'GENUINE PARTS CO',
#  'GOODRICH CORP',
#  'GOODYEAR TIRE & RUBBER CO',
#  'GRAINGER  INC',
#  'HALLIBURTON CO',
#  'L3HARRIS TECHNOLOGIES INC',
#  'HASBRO INC',
#  'WELLTOWER INC',
#  'KRAFT HEINZ CO',
#  'HELMERICH & PAYNE',
#  'HERCULES INC',
#  'HERSHEY CO',
#  'HP INC',
#  'HILTON WORLDWIDE HOLDINGS',
#  'HOLLYFRONTIER CORP',
#  'HOME DEPOT INC',
#  'HORMEL FOODS CORP',
#  'STARWOOD HOTELS&RESORTS WRLD',
#  'CENTERPOINT ENERGY INC',
#  'HUNT  TRANSPRT SVCS INC',
#  'HUNTINGTON BANCSHARES',
#  'ITT INC',
#  'ILLINOIS TOOL WORKS',
#  'TRANE TECHNOLOGIES PLC',
#  'INTEL CORP',
#  'INTL BUSINESS MACHINES CORP',
#  'INTL FLAVORS & FRAGRANCES',
#  'INTL GAME TECHNOLOGY',
#  'INTL PAPER CO',
#  'INTERPUBLIC GROUP OF COS',
#  'JACOBS ENGINEERING GROUP INC',
#  'JOHNSON & JOHNSON',
#  'JOHNSON CONTROLS INTL PLC',
#  'KLA CORP',
#  'SEARS HOLDINGS CORP',
#  'KINDER MORGAN INC',
#  'KANSAS CITY SOUTHERN',
#  'EVERGY INC',
#  'KELLOGG CO',
#  'KIMBERLY-CLARK CORP',
#  'KROGER CO',
#  'LSI CORP',
#  'LAM RESEARCH CORP',
#  'LEGGETT & PLATT INC',
#  'LEGG MASON INC',
#  'LENNAR CORP',
#  'JEFFERIES FINANCIAL GRP INC',
#  'LILLY  & CO',
#  'L BRANDS INC',
#  'LINCOLN NATIONAL CORP',
#  'KATE SPADE & CO',
#  'LOCKHEED MARTIN CORP',
#  'LOEWS CORP',
#  'RANGE RESOURCES CORP',
#  "LOWE'S COS INC",
#  'MANITOWOC CO',
#  'MARATHON OIL CORP',
#  'HOST HOTELS & RESORTS INC',
#  'MARSH & MCLENNAN COS',
#  'MARSHALL & ILSLEY CORP',
#  'MASCO CORP',
#  'MATTEL INC',
#  'MCCORMICK & CO INC',
#  "MCDONALD'S CORP",
#  'S&P GLOBAL INC',
#  'MCKESSON CORP',
#  'MEDCO HEALTH SOLUTIONS INC',
#  'MEDTRONIC PLC',
#  'CVS HEALTH CORP',
#  'MERCK & CO',
#  'MEREDITH CORP',
#  'MERRILL LYNCH & CO INC',
#  'MICRON TECHNOLOGY INC',
#  'ENTERGY CORP',
#  'MILLIPORE CORP',
#  '3M CO',
#  'MOLEX INC',
#  'MOTOROLA SOLUTIONS INC',
#  'MURPHY OIL CORP',
#  'MYLAN NV',
#  'BANK OF AMERICA CORP',
#  'NCR CORP',
#  'NATIONAL CITY CORP',
#  'TENET HEALTHCARE CORP',
#  'NATIONAL SEMICONDUCTOR CORP',
#  'NEW YORK TIMES CO',
#  'NEWELL BRANDS INC',
#  'NEWMONT CORP',
#  'NICOR INC',
#  'NIKE INC',
#  'NOBLE ENERGY INC',
#  'NORDSTROM INC',
#  'NORFOLK SOUTHERN CORP',
#  'EVERSOURCE ENERGY',
#  'NISOURCE INC',
#  'XCEL ENERGY INC',
#  'NORTHERN TRUST CORP',
#  'NORTHROP GRUMMAN CORP',
#  'TEREX CORP',
#  'WELLS FARGO & CO',
#  'NUCOR CORP',
#  'OCCIDENTAL PETROLEUM CORP',
#  'FIRSTENERGY CORP',
#  'ONEOK INC',
#  'O-I GLASS INC',
#  'PNC FINANCIAL SVCS GROUP INC',
#  'PPG INDUSTRIES INC',
#  'PACCAR INC',
#  'PG&E CORP',
#  'SEMPRA ENERGY',
#  'PALL CORP',
#  'PARKER-HANNIFIN CORP',
#  'PAYCHEX INC',
#  'PENNEY  CO',
#  'PPL CORP',
#  'PENTAIR PLC',
#  'PEPSICO INC',
#  'APPLIED BIOSYSTEMS INC',
#  'PFIZER INC',
#  'EXELON CORP',
#  'ALTRIA GROUP INC',
#  'CONOCOPHILLIPS',
#  'PVH CORP',
#  'PITNEY BOWES INC',
#  'PEPCO HOLDINGS INC',
#  'PRECISION CASTPARTS CORP',
#  'PROCTER & GAMBLE CO',
#  'PUBLIC SERVICE ENTRP GRP INC',
#  'PULTEGROUP INC',
#  'QUESTAR CORP',
#  'RAYMOND JAMES FINANCIAL CORP',
#  'RAYTHEON CO',
#  'AUTONATION INC',
#  'ROCKWELL AUTOMATION',
#  'ROHM AND HAAS CO',
#  'ROLLINS INC',
#  'ROSS STORES INC',
#  'ROWAN COMPANIES PLC',
#  'RYDER SYSTEM INC',
#  'SAFECO CORP',
#  'SAFEWAY INC',
#  'ST JUDE MEDICAL INC',
#  'HILLSHIRE BRANDS CO',
#  'SCANA CORP',
#  'SCHERING-PLOUGH',
#  'SCHLUMBERGER LTD',
#  'SEALED AIR CORP',
#  'SHERWIN-WILLIAMS CO',
#  'SIGMA-ALDRICH CORP',
#  'SMITH',
#  'SMITH INTERNATIONAL INC',
#  'SMUCKER  CO',
#  'SNAP-ON INC',
#  'KEYCORP',
#  'EDISON INTERNATIONAL',
#  'SOUTHERN CO',
#  'SOUTHWEST AIRLINES',
#  'AT&T INC',
#  'SOUTHWESTERN ENERGY CO',
#  'STANLEY BLACK & DECKER INC',
#  'STATE STREET CORP',
#  'PUBLIC STORAGE',
#  'STRYKER CORP',
#  'NAVIENT CORP',
#  'SUNOCO INC',
#  'SUNTRUST BANKS INC',
#  'SUPERVALU INC',
#  'SYSCO CORP',
#  'TECO ENERGY INC',
#  'RS LEGACY CORP',
#  'ALLEGHENY TECHNOLOGIES INC',
#  'TELEFLEX INC',
#  'TELLABS INC',
#  'TEMPLE-INLAND INC',
#  'TERADYNE INC',
#  'ANDEAVOR',
#  'TEXAS INSTRUMENTS INC',
#  'ENERGY FUTURE HOLDINGS CORP',
#  'TEXTRON INC',
#  'THERMO FISHER SCIENTIFIC INC',
#  'GLOBE LIFE INC',
#  'TOTAL SYSTEM SERVICES INC',
#  'TRIBUNE MEDIA CO',
#  'TYCO INTERNATIONAL PLC',
#  'TYSON FOODS INC',
#  'UNITED AIRLINES HOLDINGS INC',
#  'AMEREN CORP',
#  'UNION PACIFIC CORP',
#  'UDR INC',
#  'UNITEDHEALTH GROUP INC',
#  'UNITED PARCEL SERVICE INC',
#  'UST INC',
#  'RAYTHEON TECHNOLOGIES CORP',
#  'SPRINT CORP',
#  'UNIVERSAL HEALTH SVCS INC',
#  'VF CORP',
#  'VARIAN MEDICAL SYSTEMS INC',
#  'VORNADO REALTY TRUST',
#  'VULCAN MATERIALS CO',
#  'WALMART INC',
#  'WALGREENS BOOTS ALLIANCE INC',
#  'GRAHAM HOLDINGS CO',
#  "WENDY'S INTERNATIONAL INC",
#  'WESTERN DIGITAL CORP',
#  'MEADWESTVACO CORP',
#  'WEYERHAEUSER CO',
#  'WHIRLPOOL CORP',
#  'WILLIAMS COS INC',
#  'WEC ENERGY GROUP INC',
#  'ALLIANT ENERGY CORP',
#  'INTEGRYS HOLDING INC',
#  'FOOT LOCKER INC',
#  'WRIGLEY  JR CO',
#  'XEROX HOLDINGS CORP',
#  'TJX COS INC',
#  'ZIONS BANCORPORATION NA',
#  'HENRY  & ASSOCIATES',
#  'BEAR STEARNS COMPANIES INC',
#  'TRUIST FINANCIAL CORP',
#  'NOVELL INC',
#  'ANADARKO PETROLEUM CORP',
#  'NOBLE CORP PLC',
#  'EMC CORP/MA',
#  'BIG LOTS INC',
#  'MORGAN STANLEY',
#  'SUN MICROSYSTEMS INC',
#  'PRICE  GROUP',
#  'MICROSOFT CORP',
#  'ORACLE CORP',
#  'COTY INC',
#  'DIRECTV',
#  'LINEAR TECHNOLOGY CORP',
#  'GENZYME CORP',
#  'HEALTH MANAGEMENT ASSOC',
#  'HARLEY-DAVIDSON INC',
#  'GARTNER INC',
#  'ALTICE USA INC',
#  'ADOBE INC',
#  'FISERV INC',
#  'KB HOME',
#  'UNUM GROUP',
#  'COCA-COLA EUROPEAN PARTNERS',
#  'HARMAN INTERNATIONAL INDS',
#  'CERNER CORP',
#  'COMVERSE TECHNOLOGY INC',
#  'TWENTY-FIRST CENTURY FOX INC',
#  'AIRGAS INC',
#  'KRAFT FOODS GROUP INC',
#  'JOY GLOBAL INC',
#  'SYNOVUS FINANCIAL CORP',
#  'HEALTHPEAK PROPERTIES INC',
#  'PROGRESSIVE CORP-OHIO',
#  'BARR PHARMACEUTICALS INC',
#  'CADENCE DESIGN SYSTEMS INC',
#  'LEVEL 3 COMMUNICATIONS INC',
#  'CARNIVAL CORPORATION & PLC',
#  'DUKE REALTY CORP',
#  'MBIA INC',
#  'CELGENE CORP',
#  'ABIOMED INC',
#  'TIFFANY & CO',
#  'DENTSPLY SIRONA INC',
#  'VIACOMCBS INC',
#  'ZOETIS INC',
#  'SCHWAB  CORP',
#  'FASTENAL CO',
#  'MAXIM INTEGRATED PRODUCTS',
#  'FIRST REPUBLIC BANK',
#  'AMPHENOL CORP',
#  'ALTERA CORP',
#  'PIONEER NATURAL RESOURCES CO',
#  'MGM RESORTS INTERNATIONAL',
#  'ADT CORP',
#  'WASTE MANAGEMENT INC',
#  'DELL TECHNOLOGIES INC',
#  'EW SCRIPPS',
#  'FREEPORT-MCMORAN INC',
#  'NOVELLUS SYSTEMS INC',
#  'OFFICE DEPOT INC',
#  'BMC SOFTWARE INC',
#  'CINCINNATI FINANCIAL CORP',
#  'DEVON ENERGY CORP',
#  'LABORATORY CP OF AMER HLDGS',
#  'FEDERAL HOME LOAN MORTG CORP',
#  'VALERO ENERGY CORP',
#  'SIGNET JEWELERS LTD',
#  'STAPLES INC',
#  'ALLERGAN INC',
#  'PLUM CREEK TIMBER CO INC',
#  'NORTONLIFELOCK INC',
#  'ABBVIE INC',
#  'WASHINGTON MUTUAL INC',
#  "PEOPLE'S UNITED FINL INC",
#  'EOG RESOURCES INC',
#  'ELECTRONIC ARTS INC',
#  'COMMERCE BANCORP INC/NJ',
#  'SVB FINANCIAL GROUP',
#  'SANTANDER HOLDINGS USA INC',
#  'IQVIA HOLDINGS INC',
#  'NEWS CORP',
#  'MALLINCKRODT PLC',
#  'PTC INC',
#  'TWITTER INC',
#  'KEYSIGHT TECHNOLOGIES INC',
#  'CAESARS ENTERTAINMENT CORP',
#  'CABOT OIL & GAS CORP',
#  'DENBURY RESOURCES INC',
#  'SYNCHRONY FINANCIAL',
#  'ARISTA NETWORKS INC',
#  'CISCO SYSTEMS INC',
#  'HOLOGIC INC',
#  'CITIZENS FINANCIAL GROUP INC',
#  'ALLIED WASTE INDUSTRIES INC',
#  'HCA HEALTHCARE INC',
#  'XILINX INC',
#  'BAXALTA INC',
#  'BJ SERVICES CO',
#  'AUTOZONE INC',
#  'REGENERON PHARMACEUTICALS',
#  'COLUMBIA PIPELINE GROUP INC',
#  'COVENTRY HEALTH CARE INC',
#  'PMC-SIERRA INC',
#  'CEPHALON INC',
#  'UNITED STATES STEEL CORP',
#  'JONES GROUP INC',
#  'IDEXX LABS INC',
#  'AES CORP',
#  'AMBAC FINANCIAL GROUP INC',
#  'MONSTER BEVERAGE CORP',
#  'XL GROUP LTD',
#  'VERTEX PHARMACEUTICALS INC',
#  'MGIC INVESTMENT CORP/WI',
#  'BIOGEN INC',
#  'PAYPAL HOLDINGS INC',
#  'KIMCO REALTY CORP',
#  'PERRIGO CO PLC',
#  'QUALCOMM INC',
#  'GILEAD SCIENCES INC',
#  'WHOLE FOODS MARKET INC',
#  'ROPER TECHNOLOGIES INC',
#  'SYNOPSYS INC',
#  'TIME WARNER INC',
#  'MOHAWK INDUSTRIES INC',
#  'LINDE PLC',
#  'FIRST DATA CORP',
#  'BOSTON SCIENTIFIC CORP',
#  "KOHL'S CORP",
#  'BED BATH & BEYOND INC',
#  'D R HORTON INC',
#  'EXPRESS SCRIPTS HOLDING CO',
#  'STARBUCKS CORP',
#  'DYNEGY INC',
#  'MCAFEE INC',
#  'PATTERSON COS INC',
#  'COMPUWARE CORP',
#  'IAC/INTERACTIVECORP',
#  'HEWLETT PACKARD ENTERPRISE',
#  'CSRA INC',
#  'FOUR CORNERS PROPERTY TR INC',
#  'FORTIVE CORP',
#  'VERSUM MATERIALS INC',
#  'INGEVITY CORP',
#  'ADIENT PLC',
#  'SITE CENTERS CORP',
#  'CHESAPEAKE ENERGY CORP',
#  'QUALITY CARE PROPERTIES INC',
#  'ALLERGAN PLC',
#  'HUMANA INC',
#  'INTUIT INC',
#  'MICROCHIP TECHNOLOGY INC',
#  'CHUBB LTD',
#  'ADVANSIX INC',
#  'FOSSIL GROUP INC',
#  'BROOKFIELD PROPERTY REIT',
#  'SANMINA CORP',
#  "O'REILLY AUTOMOTIVE INC",
#  'ROYAL CARIBBEAN CRUISES LTD',
#  'HOWMET AEROSPACE INC',
#  'JABIL INC',
#  'XTO ENERGY INC',
#  'TRANSOCEAN LTD',
#  'ALLSTATE CORP',
#  'FLIR SYSTEMS INC',
#  'PETSMART INC',
#  'EQUITY RESIDENTIAL',
#  'BORGWARNER INC',
#  'LAMB WESTON HOLDINGS INC',
#  'KEURIG DR PEPPER INC',
#  'MARRIOTT INTL INC',
#  'VAREX IMAGING CORP',
#  'COSTCO WHOLESALE CORP',
#  'REGENCY CENTERS CORP',
#  'INCYTE CORP',
#  'URBAN OUTFITTERS INC',
#  'CARS.COM INC',
#  'NEWFIELD EXPLORATION CO',
#  'VIAVI SOLUTIONS INC',
#  'SIMON PROPERTY GROUP INC',
#  'EASTMAN CHEMICAL CO',
#  'MID-AMERICA APT CMNTYS INC',
#  'MARTIN MARIETTA MATERIALS',
#  'TRACTOR SUPPLY CO',
#  'ALBEMARLE CORP',
#  'QLOGIC CORP',
#  'INVESCO LTD',
#  'BIOVERATIV INC',
#  'WESTROCK CO',
#  'MACERICH CO',
#  'AVALONBAY COMMUNITIES INC',
#  'COPART INC',
#  'AK STEEL HOLDING CORP',
#  'PROLOGIS INC',
#  'LEHMAN BROTHERS HOLDINGS INC',
#  'NEKTAR THERAPEUTICS',
#  'ESSEX PROPERTY TRUST',
#  'APARTMENT INVST & MGMT CO',
#  'AFFILIATED COMPUTER SERVICES',
#  'REALTY INCOME CORP',
#  'TECHNIPFMC PLC',
#  'CAPITAL ONE FINANCIAL CORP',
#  'APOLLO EDUCATION GROUP INC',
#  'DOLLAR TREE INC',
#  'AMERISOURCEBERGEN CORP',
#  'BRIGHTHOUSE FINANL INC',
#  'DELPHI TECHNOLOGIES PLC',
#  'DARDEN RESTAURANTS INC',
#  'RESMED INC',
#  'BAKER HUGHES CO',
#  'JBG SMITH PPTYS',
#  'CHAMPIONX CORP',
#  'PERSPECTA INC',
#  'DOW INC',
#  'FOX CORP',
#  'COVETRUS INC',
#  'KONTOOR BRANDS INC',
#  'CORTEVA INC',
#  'CAMERON INTERNATIONAL CORP',
#  'DISH NETWORK CORP',
#  'WABTEC CORP',
#  'SUNEDISON INC',
#  'EVEREST RE GROUP LTD',
#  'DIAMOND OFFSHRE DRILLING INC',
#  'DAVITA INC',
#  'QWEST COMMUNICATION INTL INC',
#  'HENRY SCHEIN INC',
#  'SANDISK CORP',
#  'LEXMARK INTL INC',
#  'LAUDER  COS INC',
#  'WATERS CORP',
#  'NETAPP INC',
#  'CITRIX SYSTEMS INC',
#  'HARTFORD FINANCIAL SERVICES',
#  'ALEXION PHARMACEUTICALS INC',
#  'IRON MOUNTAIN INC',
#  'ALTABA INC',
#  'DEAN FOODS CO',
#  'TRAVELERS COS INC',
#  'TITANIUM METALS CORP',
#  'ANSYS INC',
#  'E TRADE FINANCIAL CORP',
#  'STERICYCLE INC',
#  'ABERCROMBIE & FITCH',
#  'ENDO INTERNATIONAL PLC',
#  'UNIVISION COMMUNICATIONS INC',
#  'IMS HEALTH HOLDINGS INC',
#  'NATIONAL OILWELL VARCO INC',
#  'MONSTER WORLDWIDE INC',
#  'QUEST DIAGNOSTICS INC',
#  'CIENA CORP',
#  'CARMAX INC',
#  'TAKE-TWO INTERACTIVE SFTWR',
#  'AMAZON.COM INC',
#  'ALEXANDRIA R E EQUITIES INC',
#  'QORVO INC',
#  'RALPH LAUREN CORP',
#  'BOSTON PROPERTIES INC',
#  'SL GREEN REALTY CORP',
#  'AMERICAN CAPITAL LTD',
#  'YUM BRANDS INC',
#  'C H ROBINSON WORLDWIDE INC',
#  'METTLER-TOLEDO INTL INC',
#  'AFFILIATED MANAGERS GRP INC',
#  'ENVISION HEALTHCARE CORP',
#  'UNITED RENTALS INC',
#  'VERISIGN INC',
#  'QUANTA SERVICES INC',
#  'BROADCOM CORP',
#  'FEDERATED HERMES INC',
#  'AMCOR PLC',
#  'NIELSEN HOLDINGS PLC',
#  'NORWEGIAN CRUISE LINE HLDGS',
#  'AMERICAN TOWER CORP',
#  'VENTAS INC',
#  'L3 TECHNOLOGIES INC',
#  'COGNIZANT TECH SOLUTIONS',
#  'KING PHARMACEUTICALS INC',
#  'REPUBLIC SERVICES INC',
#  'CONVERGYS CORP',
#  'CROWN CASTLE INTL CORP',
#  'EBAY INC',
#  'GOLDMAN SACHS GROUP INC',
#  'NVIDIA CORP',
#  'APTIV PLC',
#  'LIFE TECHNOLOGIES CORP',
#  'BOOKING HOLDINGS INC',
#  'PEPSI BOTTLING GROUP INC',
#  'CNX RESOURCES CORPORATION',
#  'REYNOLDS AMERICAN INC',
#  'F5 NETWORKS INC',
#  'SBA COMMUNICATIONS CORP',
#  'JUNIPER NETWORKS INC',
#  'HUDSON CITY BANCORP INC',
#  'RED HAT INC',
#  'BLACKROCK INC',
#  'PACTIV CORP',
#  'AKAMAI TECHNOLOGIES INC',
#  'CHARTER COMMUNICATIONS INC',
#  'EXPEDIA GROUP INC',
#  'AGILENT TECHNOLOGIES INC',
#  'PACKAGING CORP OF AMERICA',
#  'EDWARDS LIFESCIENCES CORP',
#  'METLIFE INC',
#  'FRONTIER COMMUNICATIONS CORP',
#  'NRG ENERGY INC',
#  'INTUITIVE SURGICAL INC',
#  'JANUS CAPITAL GROUP INC',
#  'ILLUMINA INC',
#  'EQUINIX INC',
#  'AVAYA INC',
#  "MOODY'S CORP",
#  'TAPESTRY INC',
#  'MONSANTO CO',
#  'ALIGN TECHNOLOGY INC',
#  'MASSEY ENERGY CO',
#  'GARMIN LTD',
#  'GLOBAL PAYMENTS INC',
#  'PEABODY ENERGY CORP',
#  'FMC TECHNOLOGIES INC',
#  'MONDELEZ INTERNATIONAL INC',
#  'PRUDENTIAL FINANCIAL INC',
#  'ACCENTURE PLC',
#  'ALLIANCE DATA SYSTEMS CORP',
#  'WILLIS TOWERS WATSON PLC',
#  'ROCKWELL COLLINS',
#  'ZIMMER BIOMET HOLDINGS INC',
#  'ANTHEM INC',
#  'GAMESTOP CORP',
#  'CENTENE CORP',
#  'PRINCIPAL FINANCIAL GRP INC',
#  'ADVANCE AUTO PARTS INC',
#  'ACUITY BRANDS INC',
#  'LORILLARD INC',
#  'NETFLIX INC',
#  'TRANSDIGM GROUP INC',
#  'CME GROUP INC',
#  'WYNN RESORTS LTD',
#  'NASDAQ INC',
#  'CIT GROUP INC',
#  'CIMAREX ENERGY CO',
#  'SEAGATE TECHNOLOGY PLC',
#  'QEP RESOURCES INC',
#  'LKQ CORP',
#  'ASSURANT INC',
#  'SALESFORCE.COM INC',
#  'GENWORTH FINANCIAL INC',
#  'MARKETAXESS HOLDINGS INC',
#  'MASTERCARD INC',
#  'HOSPIRA INC',
#  'METROPCS COMMUNICATIONS INC',
#  'ALPHABET INC',
#  'EXTRA SPACE STORAGE INC',
#  'DIGITAL REALTY TRUST INC',
#  'MOSAIC CO',
#  'CELANESE CORP',
#  'ALPHA NATURAL RESOURCES INC',
#  'IHS MARKIT LTD',
#  'INTERCONTINENTAL EXCHANGE',
#  'CF INDUSTRIES HOLDINGS INC',
#  'DISCOVERY INC',
#  'AMERIPRISE FINANCIAL INC',
#  'UNDER ARMOUR INC',
#  'LEIDOS HOLDINGS INC',
#  'VIACOM INC',
#  'CHIPOTLE MEXICAN GRILL INC',
#  'FIDELITY NATIONAL INFO SVCS',
#  'NYSE EURONEXT',
#  'FACEBOOK INC',
#  'DIAMONDBACK ENERGY INC',
#  'PHILLIPS 66',
#  'REALOGY HOLDINGS CORP',
#  'EMBARQ CORP',
#  'WINDSTREAM HOLDINGS INC',
#  'WYNDHAM DESTINATIONS INC',
#  'WESTERN UNION CO',
#  'HANESBRANDS INC',
#  'FIRST SOLAR INC',
#  'IPG PHOTONICS CORP',
#  'SPECTRA ENERGY CORP',
#  'TIME WARNER CABLE INC',
#  'BROADRIDGE FINANCIAL SOLUTNS',
#  'COVIDIEN PLC',
#  'TE CONNECTIVITY LTD',
#  'DISCOVER FINANCIAL SVCS',
#  'CONCHO RESOURCES INC',
#  'TERADATA CORP',
#  'MSCI INC',
#  'ULTA BEAUTY INC',
#  'AMERICAN WATER WORKS CO INC',
#  'VISA INC',
#  'PHILIP MORRIS INTERNATIONAL',
#  'DR PEPPER SNAPPLE GROUP INC',
#  'SCRIPPS NETWORKS INTERACTIVE',
#  'ACTIVISION BLIZZARD INC',
#  'VERISK ANALYTICS INC',
#  'BROADCOM INC',
#  'MEAD JOHNSON NUTRITION CO',
#  'CAREFUSION CORP',
#  'FORTINET INC',
#  'CBOE GLOBAL MARKETS INC',
#  'FLEETCOR TECHNOLOGIES INC',
#  'MOTOROLA MOBILITY HLDGS INC',
#  'HUNTINGTON INGALLS IND INC',
#  'MARATHON PETROLEUM CORP',
#  'WPX ENERGY INC',
#  'FORTUNE BRANDS HOME & SECUR',
#  'XYLEM INC',
#  'CAPRI HOLDINGS LTD',
#  'TRIPADVISOR INC',
#  'CBRE GROUP INC',
#  'WELLCARE HEALTH PLANS INC',
#  'LYONDELLBASELL INDUSTRIES NV',
#  'ALLEGION PLC',
#  'NVENT ELECTRIC PLC']

# %%
df['Company']=cp

# %%
df['Company'] = df['Company'].str.replace('-', ' ')
df['Company'] = df['Company'].str.replace('VERIZONMMUNICATIONS', 'VERIZON COMMUNICATIONS')
df['Company']= df.Company.str.strip()

# %%
tdf=pd.DataFrame()
companies=[]
gvk=[]
handles=[]
descriptions=[]
verified=[]

badnames=[]
badgv=[]

for i in range(len(df)):
    users = api.search_users(df.iloc[i]['Company'])                     
    lst=[]
    for user in users:
        lst.append(user.screen_name)
    if len(lst)==0:
        badnames.append(df.iloc[i]['CompanyName'])
        badgv.append(df.iloc[i]['GVKEY'])
        print('--------------------------------- ',df.iloc[i]['Company'],'---------------------------------' )
    for j in lst:
        obj=api.get_user(j)
        result=obj.verified
        if result==True:
            companies.append(df.iloc[i]['CompanyName'])
            gvk.append(df.iloc[i]['GVKEY'])
            handles.append(j)
            descriptions.append(obj.description)
            verified.append(result)
            print(df.iloc[i]['Company'],'----', j)
# Out:
# ---------------------------------  ADC TELECOMMUNICATIONS ---------------------------------
# AMERICAN AIRLINES ---- AmericanAir
# AMERICAN AIRLINES ---- AAarena
# AMERICAN AIRLINES ---- uptin
# AMERICAN AIRLINES ---- rosebaca
# AMERICAN AIRLINES ---- LATAMAirlines
# ---------------------------------  PINNACLE WEST CAPITAL ---------------------------------
# ABBOTT LABORATORIES ---- AbbottNews
# ADVANCED MICRO DEVICES ---- AMD
# ADVANCED MICRO DEVICES ---- AMDGaming
# ADVANCED MICRO DEVICES ---- AMD_UK
# AETNA INC ---- Aetna
# AIR PRODUCTS & CHEMICALS ---- airproducts
# ALASKA AIR ---- AlaskaAir
# ALASKA AIR ---- RavnAlaska
# HONEYWELL INTERNATIONAL ---- honeywell
# ---------------------------------  ALLTEL CORP ---------------------------------
# ALCOA INC ---- Alcoa
# AMERICAN ELECTRIC POWER ---- AEPnews
# AMERICAN EXPRESS ---- AmericanExpress
# AMERICAN EXPRESS ---- AmexUK
# AMERICAN EXPRESS ---- AmexBusiness
# AMERICAN EXPRESS ---- AskAmex
# AMERICAN EXPRESS ---- AmexBusinessCan
# AMERICAN EXPRESS ---- theamexgolf
# AMERICAN EXPRESS ---- AmexBusinessUK
# AMERICAN EXPRESS ---- aafexpress
# AMERICAN EXPRESS ---- BSTHydePark
# AMERICAN EXPRESS ---- AmexNL
# AMERICAN EXPRESS ---- KabbageInc
# AMERICAN EXPRESS ---- amex_express_mx
# ---------------------------------  AFLAC INC ---------------------------------
# AMERICAN INTERNATIONAL ---- AIGinsurance
# AMERICAN INTERNATIONAL ---- CAAM
# AMERICAN INTERNATIONAL ---- theAGU
# AMERICAN INTERNATIONAL ---- americansoulbet
# AMERICAN INTERNATIONAL ---- TheAHL
# AMERICAN INTERNATIONAL ---- CAREGlobal
# AMERICAN INTERNATIONAL ---- JAMA_current
# AMERICAN INTERNATIONAL ---- MerriamWebster
# AMERICAN INTERNATIONAL ---- USAID
# AMERICAN INTERNATIONAL ---- AACSB
# AMGEN INC ---- Amgen
# AMGEN INC ---- AmgenOncology
# AMGEN INC ---- AmgenGermany
# ---------------------------------  NABORS INDUSTRIES LTD ---------------------------------
# ---------------------------------  ANHEUSER BUSCHS ---------------------------------
# APPLE INC ---- Apple
# APPLE INC ---- pschiller
# APPLE INC ---- AngelaAhrendts
# APPLE INC ---- BoysStateMovie
# APPLE INC ---- trippmickle
# APPLE INC ---- DaveAtBEATS
# ---------------------------------  ASHLAND GLOBAL HOLDINGS ---------------------------------
# SOUTHERN GAS ---- SSGC_Official
# AUTODESK INC ---- autodesk
# AUTOMATIC DATA PROCESSING ---- ADP
# AVERY DENNISON ---- AveryDennison
# AVON PRODUCTS ---- AvonInsider
# AVON PRODUCTS ---- Avon_UK
# AVON PRODUCTS ---- AvonIndia
# AVON PRODUCTS ---- avonturkiye
# BAKER HUGHES ---- Avitas_Systems
# CONSTELLATION ENERGY ---- ConstellationEG
# BANK OF NEW YORK MELLON ---- BNYMellon
# VERIZON COMMUNICATIONS ---- Verizon
# VERIZON COMMUNICATIONS ---- vzpublicsector
# VERIZON COMMUNICATIONS ---- FrontierCorp
# VERIZON COMMUNICATIONS ---- XOComm
# BEMIS ---- SayAnythingMuz
# BEMIS ---- maxbemis
# BEMIS ---- SDuPreeBemis
# BEMIS ---- TomBemis
# BEMIS ---- SBemisOnline
# BEST BUY ---- BestBuy
# BEST BUY ---- BBYNews
# BEST BUY ---- BestBuyCanada
# BEST BUY ---- BestBuyCSR
# BEST BUY ---- BestBuyCanHelp
# BEST BUY ---- BestBuy_Deals
# BEST BUY ---- BBYInfluencers
# BEST BUY ---- BestBuyBusiness
# BEST BUY ---- BestBuySupport
# BEST BUY ---- BestBuyEdu
# BLACK & DECKER ---- BLACKANDDECKER
# BLACK & DECKER ---- StanleyBlkDeckr
# BLACK & DECKER ---- RamanaGogula
# BLOCK H & R ---- HRBlock
# BLOCK H & R ---- HRBlockAnswers
# BLOCK H & R ---- HRBlockNews
# BLOCK H & R ---- HRBlockCanada
# BOEING CO ---- Boeing_In
# BOEING CO ---- united
# OFFICEMAX INC ---- OfficeMax
# OFFICEMAX INC ---- officedepot
# ROBERT HALF ---- roberthalf
# ROBERT HALF ---- RobertHalfTech
# ROBERT HALF ---- RobertHalfMR
# ROBERT HALF ---- RobertHalfFA
# ROBERT HALF ---- RobertZepeda
# ROBERT HALF ---- RobdaBank
# BRISTOL MYERS SQUIBB ---- bmsnews
# BRISTOL MYERS SQUIBB ---- ScienceAtBMS
# BROWN FORMAN ---- brownforman
# BROWN FORMAN ---- brownformanuk
# BROWN FORMAN ---- coopers_craft
# BURLINGTON NORTHERN SANTA FE ---- BNSFRailway
# ---------------------------------  UNISYS CORP ---------------------------------
# ---------------------------------  CIGNA CORP ---------------------------------
# ---------------------------------  CSX CORP ---------------------------------
# CAMPBELL SOUP ---- CampbellSoupCo
# CAMPBELL SOUP ---- CampbellsChunky
# CAMPBELL SOUP ---- LifeAfterTGame
# CONSTELLATION BRANDS ---- cbrands
# CONSTELLATION BRANDS ---- PenskeMedia
# CARDINAL HEALTH ---- cardinalhealth
# PROGRESS ENERGY ---- EnergyCIO
# PROGRESS ENERGY ---- Shell_US
# PROGRESS ENERGY ---- mankofit
# PROGRESS ENERGY ---- Exelon
# CATERPILLAR INC ---- CaterpillarInc
# ---------------------------------  CENTURYLINK INC ---------------------------------
# JPMORGAN CHASE & ---- jpmorgan
# JPMORGAN CHASE & ---- Chase
# JPMORGAN CHASE & ---- ChaseSupport
# JPMORGAN CHASE & ---- MellodyHobson
# JPMORGAN CHASE & ---- IVMFSyracuseU
# JPMORGAN CHASE & ---- hhigginbottom
# JPMORGAN CHASE & ---- MichelleF_Davis
# JPMORGAN CHASE & ---- WePay
# JPMORGAN CHASE & ---- pre_me
# CHEVRON CORP ---- Chevron
# CHUBB CORP ---- Chubb
# CHUBB CORP ---- ChubbNA
# ---------------------------------  CIRCUIT CITY STORES ---------------------------------
# IHEARTMEDIA INC ---- iHeartMedia
# IHEARTMEDIA INC ---- Rock1053
# IHEARTMEDIA INC ---- michellemlanz
# CLOROX CO ---- CloroxCo
# COCA COLA CO ---- CocaColaCo
# COCA COLA CO ---- CocaColaCo_ca
# COCA COLA CO ---- CocaColaAU_Co
# COCA COLA CO ---- CocaCola_Ind
# COCA COLA CO ---- ThumsUpOfficial
# COCA COLA CO ---- MaazaIndia
# COCA COLA CO ---- sprite_india
# COCA COLA CO ---- Fanta_India
# COCA COLA CO ---- CocaColaRoxy
# COCA COLA CO ---- cocacolaie
# COCA COLA CO ---- eveharlow
# COCA COLA CO ---- CocaColaCoCL
# COCA COLA CO ---- CocaColaCoPY
# COCA COLA CO ---- CocaColaCo_PE
# COCA COLA CO ---- CocaColaCoUY
# COCA COLA CO ---- CocaColaCo_es
# COCA COLA CO ---- CocaColaCoAR
# COCA COLA CO ---- CocaColaCoBO
# AON PLC ---- Aon_plc
# AON PLC ---- XSchauffele
# CITIGROUP INC ---- Citi
# CA INC ---- MarvelStudiosCA
# CA INC ---- eBayCanada
# CA INC ---- CAinc
# CA INC ---- CA_IM
# DXC TECHNOLOGY ---- DXCTechnology
# CONAGRA BRANDS ---- ConagraBrands
# CONAGRA BRANDS ---- GlutinoFoods
# CONAGRA BRANDS ---- jonjayharris
# CONSOLIDATED EDISON ---- ConEdison
# COOPERS ---- PwC
# COOPERS ---- PwCUS
# COOPERS ---- PwC_UK
# COOPERS ---- coopers_craft
# COOPERS ---- PwC_Nigeria
# COOPERS ---- PwCTax
# ---------------------------------  MOLSONORS BEVERAGE ---------------------------------
# CORNING INC ---- Corning
# CORNING INC ---- OwensCorning
# CORNING INC ---- OCInsulation
# COUNTRYWIDE FINANCIAL ---- BankofAmerica
# COUNTRYWIDE FINANCIAL ---- BofA_News
# COUNTRYWIDE FINANCIAL ---- BofA_Tips
# CUMMINS INC ---- Cummins
# DEERE & ---- dearDEERE
# DEERE & ---- JohnDeere
# DEERE & ---- JDCLASSIC
# DEERE & ---- JuddPDeere45
# DELTA AIR LINES ---- Delta
# DELTA AIR LINES ---- Delta_Pilots
# DELTA AIR LINES ---- DeltaNewsHub
# DELTA AIR LINES ---- DeltaVacations
# DTE ENERGY ---- DTE_Energy
# ADTALEM GLOBAL EDUCATION ---- lisawwardell
# ADTALEM GLOBAL EDUCATION ---- adtalemglobal
# ---------------------------------  DILLARDS INC ---------------------------------
# DISNEY  CO ---- WaltDisneyCo
# DISNEY  CO ---- WDWToday
# DISNEY  CO ---- DisneyPlusUK
# DISNEY  CO ---- DisneyXDUK
# DISNEY  CO ---- PixarSoul
# DISNEY  CO ---- DisneyCareers
# DISNEY  CO ---- DisneyGiftCard
# DISNEY  CO ---- Disney_Insiders
# DISNEY  CO ---- DisneyStudiosIE
# DISNEY  CO ---- DisneyPlusHelp
# DISNEY  CO ---- abigaildisney
# DISNEY  CO ---- WDWGuestService
# DISNEY  CO ---- hotstar_helps
# DOLLAR GENERAL ---- DollarGeneral
# DOMINION ENERGY ---- DominionEnergy
# DOMINION ENERGY ---- DECCGolf
# DOMINION ENERGY ---- DomEnergyOhio
# DOMINION ENERGY ---- Dom_CovePoint
# DOMINION ENERGY ---- Dom_Millstone
# DUPONT DE NEMOURS ---- DuPont_News
# OMNICOM GROUP ---- Omnicom
# OMNICOM GROUP ---- MikeCooper_33
# OMNICOM GROUP ---- mdenardis
# DU PONT  DE NEMOURS ---- DuPont_News
# DUKE ENERGY ---- DukeEnergy
# DUN & BRADSTREET ---- DunBradstreet
# DUN & BRADSTREET ---- Stibel
# EASTMAN KODAK ---- Kodak
# EASTMAN KODAK ---- EastmanMuseum
# EASTMAN KODAK ---- Carestream
# EATON ---- eatoncorp
# EATON ---- AshtonJEaton
# EATON ---- georgeeaton
# EATON ---- AbbieEaton44
# EATON ---- MerEaton
# EATON ---- btheiseneaton
# EATON ---- BrandoEaton
# EATON ---- joshua_eaton
# EATON ---- LongEatonNorth
# EATON ---- courtneyeaton
# EATON ---- njerieaton
# EATON ---- PaulDEaton52
# EATON ---- CollinEatonHC
# EL PASO ---- elpasotimes
# EL PASO ---- ElPasoTXGov
# EL PASO ---- EPPOLICE
# EL PASO ---- eplocomotivefc
# EL PASO ---- oldelpaso
# EL PASO ---- NWSElPaso
# EL PASO ---- UTEP
# EL PASO ---- FBIElPaso
# EL PASO ---- EPCPublicHealth
# EL PASO ---- 600espnelpaso
# EMERSON ELECTRIC ---- Emerson_News
# EMERSON ELECTRIC ---- EmersonComRes
# WEATHERFORD ---- WeatherfordCorp
# WEATHERFORD ---- willweatherford
# WEATHERFORD ---- sincerelyash
# WEATHERFORD ---- Weatherford5
# ATMOS ENERGY ---- atmosenergy
# EQUIFAX INC ---- Equifax
# ---------------------------------  EXPEDITORS WASH ---------------------------------
# EXXON MOBIL ---- exxonmobil
# EXXON MOBIL ---- ExxonMobil_EU
# EXXON MOBIL ---- exxonmobil_aus
# EXXON MOBIL ---- ExxonMobil_UK
# EXXON MOBIL ---- exxonmobil_sg
# EXXON MOBIL ---- ExxonMobil_PNG
# EXXON MOBIL ---- exxonmobilbmt
# EXXON MOBIL ---- XOM_Chemical
# EXXON MOBIL ---- exxonmobil_ind
# EXXON MOBIL ---- XOM_NatGas
# EXXON MOBIL ---- XOMFoundation
# EXXON MOBIL ---- exxonmobil_th
# EXXON MOBIL ---- ExxonMobil_ID
# EXXON MOBIL ---- ExxonMobil_GER
# NEXTERA ENERGY ---- NextEraEnergyR
# NEXTERA ENERGY ---- nexteraenergy
# NEXTERA ENERGY ---- pmusser
# FAMILY DOLLAR STORES ---- myfamilydollar
# ---------------------------------  FEDERAL NATIONAL MORTGA ASSN ---------------------------------
# ---------------------------------  FEDERAL REALTY INVESTMENT TR ---------------------------------
# MACY'S INC ---- Macys
# FIFTH THIRD BANCORP ---- FifthThird
# REGIONS FINANCIAL ---- askRegions
# M & T BANK ---- MandT_Bank
# M & T BANK ---- CentralBank_TR
# M & T BANK ---- MandSBank
# M & T BANK ---- RHBGroup
# M & T BANK ---- tymebankza
# M & T BANK ---- Merkez_Bankasi
# M & T BANK ---- Banxico
# M & T BANK ---- _Ekstraklasa_
# U S BANCORP ---- usbank
# ---------------------------------  FIRST HORIZON NATIONAL ---------------------------------
# FORD MOTOR ---- Ford
# FORD MOTOR ---- FordAustralia
# FORD MOTOR ---- sundeep
# FORD MOTOR ---- FordCanada
# FORD MOTOR ---- FordServiceCA
# FORD MOTOR ---- FordFund
# FORD MOTOR ---- FordPhilippines
# FORD MOTOR ---- FordIreland
# FORD MOTOR ---- mtruby
# FORD MOTOR ---- FordSpain
# FORD MOTOR ---- fordvenezuela
# FOREST LABORATORIES ---- meury_bill
# FRANKLIN RESOURCES ---- MartinCurrieIM
# TEGNA INC ---- TEGNA
# TEGNA INC ---- LarryAudas
# GAP INC ---- GapInc
# GAP INC ---- Gap
# GAP INC ---- Gap_JP
# GENERAL DYNAMICS ---- generaldynamics
# GENERAL DYNAMICS ---- GDMS
# GENERAL DYNAMICS ---- GD_LandSystems
# GENERAL DYNAMICS ---- GDIT
# GENERAL DYNAMICS ---- gduknews
# GENERAL DYNAMICS ---- GD_OTS
# GENERAL DYNAMICS ---- GDMS_C
# GENERAL DYNAMICS ---- GDElectricBoat
# GENERAL DYNAMICS ---- gdukrecruitment
# GENERAL ELECTRIC ---- generalelectric
# GENERAL ELECTRIC ---- GEpublicaffairs
# GENERAL ELECTRIC ---- GDElectricBoat
# GENERAL ELECTRIC ---- tgryta
# GENERAL ELECTRIC ---- GELighting
# GENERAL ELECTRIC ---- GE_Turkiye
# GENERAL ELECTRIC ---- GEAustralia
# GENERAL ELECTRIC ---- GEAviation
# GENERAL ELECTRIC ---- larryculpjr
# GENERAL ELECTRIC ---- GE_France
# GENERAL ELECTRIC ---- AECC_Aberdeen
# GENERAL MILLS ---- GeneralMills
# GENERAL MILLS ---- GenMillsCereal
# GENERAL MILLS ---- GenMillsCareers
# GENERAL MOTORS ---- GM
# GENERAL MOTORS ---- GMBPress
# GENERAL MOTORS ---- MFG_GM
# GENERAL MOTORS ---- GMFleet
# GENERAL MOTORS ---- vauxhall
# GENERAL MOTORS ---- GMC
# GENERAL MOTORS ---- GeneralMotorsMx
# GENERAL MOTORS ---- jlareauan
# GENERAL MOTORS ---- ChevroletArg
# GENERAL MOTORS ---- GMArgPress
# GENERAL MOTORS ---- chevrolet
# GENUINE PARTS ---- GMParts_ACDelco
# GENUINE PARTS ---- NAPAKnowHow
# GENUINE PARTS ---- baxiboilers
# GOODYEAR TIRE & RUBBER ---- goodyear
# GRAINGER  INC ---- grainger
# HALLIBURTON CO ---- Halliburton
# HASBRO INC ---- Hasbro
# HASBRO INC ---- atari
# ---------------------------------  WELLTOWER INC ---------------------------------
# KRAFT HEINZ ---- KraftHeinzCo
# KRAFT HEINZ ---- khpantryday
# KRAFT HEINZ ---- myfoodandfamily
# KRAFT HEINZ ---- KraftHeinzCan
# KRAFT HEINZ ---- HeinzUK
# KRAFT HEINZ ---- heinzmayo
# HERSHEY CO ---- AskHershey
# HERSHEY CO ---- Hersheypark
# HP INC ---- HP
# HP INC ---- palm
# HP INC ---- EnriqueJLores
# HP INC ---- HP_PC_JP
# HP INC ---- SUNRISE_web
# HILTON WORLDWIDE HOLDINGS ---- HiltonHotels
# HILTON WORLDWIDE HOLDINGS ---- HiltonHonors
# HILTON WORLDWIDE HOLDINGS ---- HiltonNewsroom
# ---------------------------------  HOLLYFRONTIER CORP ---------------------------------
# HOME DEPOT ---- HomeDepot
# HOME DEPOT ---- HomeDepotCanada
# HOME DEPOT ---- HomeDepotCareer
# HOME DEPOT ---- HomeDepotGR
# HOME DEPOT ---- HomeDepotFound
# HOME DEPOT ---- HDCares
# HORMEL FOODS ---- HormelFoods
# ---------------------------------  STARWOOD HOTELS&RESORTS WRLD ---------------------------------
# ---------------------------------  HUNT  TRANSPRT ---------------------------------
# HUNTINGTON BANCSHARES ---- Huntington_Bank
# ITT INC ---- TheHartford
# ---------------------------------  INTL BUSINESS MACHINES ---------------------------------
# ---------------------------------  INTL FLAVORS & FRAGRANCES ---------------------------------
# ---------------------------------  INTERPUBLIC OFS ---------------------------------
# JACOBS ENGINEERING ---- UCSDJacobs
# JACOBS ENGINEERING ---- FredericJacobs
# JOHNSON & JOHNSON ---- JNJNews
# JOHNSON & JOHNSON ---- SenRonJohnson
# JOHNSON & JOHNSON ---- MagicJohnson
# JOHNSON & JOHNSON ---- JNJCares
# JOHNSON & JOHNSON ---- xoBetseyJohnson
# JOHNSON & JOHNSON ---- GovGaryJohnson
# JOHNSON & JOHNSON ---- ShawnJohnson
# JOHNSON & JOHNSON ---- TheRock
# JOHNSON & JOHNSON ---- JimmieJohnson
# JOHNSON & JOHNSON ---- RepDustyJohnson
# JOHNSON & JOHNSON ---- rianjohnson
# JOHNSON & JOHNSON ---- jackjohnson
# JOHNSON & JOHNSON ---- DJohnsonPGA
# JOHNSON & JOHNSON ---- MightyMouse
# JOHNSON & JOHNSON ---- ochocinco
# JOHNSON & JOHNSON ---- BorisJohnson
# JOHNSON & JOHNSON ---- NASA_Johnson
# JOHNSON & JOHNSON ---- bennyjohnson
# JOHNSON & JOHNSON ---- LaneJohnson65
# ---------------------------------  JOHNSONNTROLS ---------------------------------
# ---------------------------------  KLA CORP ---------------------------------
# SEARS HOLDINGS ---- Sears
# KANSAS CITY SOUTHERN ---- ATFKansasCity
# KANSAS CITY SOUTHERN ---- ETeaparty25
# KELLOGG CO ---- KelloggSchool
# KELLOGG CO ---- KelloggCompany
# KELLOGG CO ---- CelesteKellogg
# KELLOGG CO ---- KelloggsUKI
# KELLOGG CO ---- jordankellogg
# KELLOGG CO ---- paperhaus
# KELLOGG CO ---- pang
# KELLOGG CO ---- ghanshyamtiwari
# KIMBERLY CLARK CORP ---- KCCorp
# KROGER CO ---- kroger
# KROGER CO ---- KrogerNews
# LEGG MASON ---- CitiOpen
# LENNAR CORP ---- Lennar
# JEFFERIES FINANCIAL ---- HandlerRich
# LILLY  & ---- Lilly
# LILLY  & ---- LillyPad
# LILLY  & ---- latewithlilly
# LILLY  & ---- EvangelineLilly
# LILLY  & ---- lilly_wachowski
# LILLY  & ---- IUPhilanthropy
# LILLY  & ---- lillygoodman
# LILLY  & ---- AmeliaLilyOffic
# LILLY  & ---- LillySinghFans
# LILLY  & ---- LillyPulitzer
# LILLY  & ---- LillyPadCA
# LILLY  & ---- LillyPadEU
# LILLY  & ---- LillyMedical
# LILLY  & ---- LillyDiabetes
# LILLY  & ---- LillyCareers
# L BRANDS ---- LNforBrands
# L BRANDS ---- l3pje
# L BRANDS ---- LVMH
# L BRANDS ---- MDLZ
# L BRANDS ---- BATplc
# L BRANDS ---- joeybrezinski
# LINCOLN NATIONAL ---- LincolnUSForest
# LINCOLN NATIONAL ---- lincolnfingroup
# LINCOLN NATIONAL ---- NationalMallNPS
# LINCOLN NATIONAL ---- MITLL
# LINCOLN NATIONAL ---- LincolnBoyhood
# LINCOLN NATIONAL ---- LincolnBirthNPS
# LINCOLN NATIONAL ---- NWSLincolnIL
# LINCOLN NATIONAL ---- lincolnSU
# LINCOLN NATIONAL ---- National_Ag_Lib
# LINCOLN NATIONAL ---- fordstheatre
# LINCOLN NATIONAL ---- LincolnHomeNPS
# KATE SPADE & ---- katespadeny
# LOCKHEED MARTIN ---- LockheedMartin
# LOCKHEED MARTIN ---- lmnews
# LOCKHEED MARTIN ---- LMUKNews
# LOCKHEED MARTIN ---- thef35
# LOCKHEED MARTIN ---- LMIndiaNews
# LOCKHEED MARTIN ---- LMCanadaNews
# LOCKHEED MARTIN ---- LMMiddleEast
# LOCKHEED MARTIN ---- LMPolandNews
# LOCKHEED MARTIN ---- LMGermanyNews
# LOCKHEED MARTIN ---- ArmedForcesBowl
# LOCKHEED MARTIN ---- LMJapanNews
# RANGE RESOURCES ---- SignifyUni
# ---------------------------------  MARSH & MCLENNANS ---------------------------------
# ---------------------------------  MARSHALL & ILSLEY ---------------------------------
# ---------------------------------  MASCO CORP ---------------------------------
# MATTEL INC ---- Mattel
# MCCORMICK & ---- McCormickCorp
# MCCORMICK & ---- SierraNMcCormic
# MCCORMICK & ---- mccormickspices
# MCCORMICK & ---- TyMcCormick
# MCCORMICK & ---- McCormickJohn
# MCCORMICK & ---- KathrynrMcc
# MCCORMICK & ---- neil_mccormick
# MCCORMICK & ---- cmccormick08
# MCCORMICK & ---- sadogre
# MCCORMICK & ---- emily_mcck
# MCCORMICK & ---- HyattMcCormick
# MCCORMICK & ---- McCormick4Chefs
# MCCORMICK & ---- RichforGA
# MCDONALD'S CORP ---- McDonaldsCorp
# S&P GLOBAL ---- SPGlobal
# S&P GLOBAL ---- SPGlobalRatings
# S&P GLOBAL ---- SPGMarketIntel
# S&P GLOBAL ---- Leonardo_live
# S&P GLOBAL ---- Leonardo_UK
# S&P GLOBAL ---- pmnewsnigeria
# S&P GLOBAL ---- CHEXNewswatch
# S&P GLOBAL ---- taykuy
# S&P GLOBAL ---- JDBlum23
# ---------------------------------  MEDCO HEALTH SOLUTIONS ---------------------------------
# MEDTRONIC PLC ---- Medtronic
# CVS HEALTH ---- CVSHealth
# CVS HEALTH ---- CVSHealthJobs
# CVS HEALTH ---- CVSClassicGolf
# CVS HEALTH ---- CVSHealthIR
# CVS HEALTH ---- CVSCareers
# CVS HEALTH ---- cvspharmacy
# CVS HEALTH ---- CVSinAction
# CVS HEALTH ---- ndegreve
# CVS HEALTH ---- AlanLotvinMD
# MERCK & ---- Merck
# MERCK & ---- merckgroup
# MERCK & ---- MerckforMothers
# MERCK & ---- USMerckProducts
# MERCK & ---- MMercuriadis
# MERCK & ---- MerckManualPro
# MERCK & ---- merck50
# MERCK & ---- MerckManualHome
# MEREDITH CORP ---- MeredithCorp
# MERRILL LYNCH & ---- MerrillLynch
# MERRILL LYNCH & ---- SallieKrawcheck
# MERRILL LYNCH & ---- MarshallM13
# MICRON TECHNOLOGY ---- MicronTech
# ---------------------------------  ENTERGY CORP ---------------------------------
# 3M CO ---- 3M
# 3M CO ---- 3MAuto
# 3M CO ---- 3MJapan
# 3M CO ---- codeofvets
# 3M CO ---- 3MEspana
# ---------------------------------  MOLEX INC ---------------------------------
# MOTOROLA SOLUTIONS ---- MotoSolutions
# MOTOROLA SOLUTIONS ---- Moto
# MYLAN NV ---- MylanNews
# BANK OF AMERICA ---- BankofAmerica
# BANK OF AMERICA ---- BofA_News
# BANK OF AMERICA ---- BofA_Tips
# BANK OF AMERICA ---- BofAPrivateBank
# BANK OF AMERICA ---- BofAstadium
# BANK OF AMERICA ---- BofA_Help
# BANK OF AMERICA ---- BofA_Business
# BANK OF AMERICA ---- stlouisfed
# BANK OF AMERICA ---- ChiMarathon
# BANK OF AMERICA ---- joanneprada
# BANK OF AMERICA ---- utahfoodbank
# BANK OF AMERICA ---- BenEisen
# BANK OF AMERICA ---- AnneFinucane
# BANK OF AMERICA ---- BofA_Careers
# BANK OF AMERICA ---- CoBank
# BANK OF AMERICA ---- AndreaSmithCLT
# ---------------------------------  NCR CORP ---------------------------------
# NATIONAL CITY ---- CityOfNatlCity
# NATIONAL CITY ---- CityNational
# NATIONAL CITY ---- OKCNM
# NATIONAL CITY ---- NWSKansasCity
# NATIONAL CITY ---- NACCHOalerts
# NATIONAL CITY ---- NALC_National
# NATIONAL CITY ---- OfficialClarets
# NATIONAL CITY ---- BathCity_FC
# NEW YORK TIMES ---- nytimes
# NEW YORK TIMES ---- nytimesworld
# NEW YORK TIMES ---- nytimesarts
# NEW YORK TIMES ---- nytimesbooks
# NEW YORK TIMES ---- nytopinion
# NEW YORK TIMES ---- nytimesmusic
# NEW YORK TIMES ---- nytvideo
# NEW YORK TIMES ---- VVFriedman
# NEW YORK TIMES ---- nytpolitics
# NEW YORK TIMES ---- ShaneGoldmacher
# NEW YORK TIMES ---- EllenBarryNYT
# NEW YORK TIMES ---- jmartNYT
# NEW YORK TIMES ---- meredith_levien
# NEW YORK TIMES ---- michpoligal
# NEW YORK TIMES ---- MarkLandler
# NEW YORK TIMES ---- benyt
# NEW YORK TIMES ---- ManohlaDargis
# NEW YORK TIMES ---- mirjordan
# NEW YORK TIMES ---- vindugoel
# ---------------------------------  NICOR INC ---------------------------------
# NIKE INC ---- Nike
# NIKE INC ---- nikefootball
# NIKE INC ---- nikestore
# NIKE INC ---- nikebasketball
# NIKE INC ---- Withrow26
# NIKE INC ---- ClementDaguin9
# EVERSOURCE ENERGY ---- EversourceCorp
# EVERSOURCE ENERGY ---- EversourceNH
# EVERSOURCE ENERGY ---- EversourceCT
# EVERSOURCE ENERGY ---- EversourceMA
# XCEL ENERGY ---- XcelEnergyCtr
# NORTHERN TRUST ---- NorthernTrust
# NORTHERN TRUST ---- thegenesisinv
# NORTHERN TRUST ---- NTcareers
# NORTHERN TRUST ---- TheNTGolf
# NORTHERN TRUST ---- NTWealth
# NORTHERN TRUST ---- NTInvest
# NORTHERN TRUST ---- NHSNLaG
# NORTHERN TRUST ---- ndht
# NORTHERN TRUST ---- SheffieldHosp
# NORTHERN TRUST ---- NCAlliance_NHS
# NORTHROP GRUMMAN ---- northropgrumman
# NORTHROP GRUMMAN ---- NGCNews
# NORTHROP GRUMMAN ---- NG_Careers
# NORTHROP GRUMMAN ---- thef35
# NORTHROP GRUMMAN ---- MilitaryBowl
# WELLS FARGO & ---- WellsFargo
# WELLS FARGO & ---- WellsFargoGolf
# WELLS FARGO & ---- Ask_WellsFargo
# WELLS FARGO & ---- WellsFargoJobs
# WELLS FARGO & ---- WellsFargoCtr
# WELLS FARGO & ---- WFAssetMgmt
# WELLS FARGO & ---- WFInvesting
# WELLS FARGO & ---- BenEisen
# WELLS FARGO & ---- dustinbwilson1
# ---------------------------------  ONEOK INC ---------------------------------
# PNC FINANCIAL ---- PNCBank
# PNC FINANCIAL ---- PNCNews
# PNC FINANCIAL ---- AmandaAgatiPNC
# PPG INDUSTRIES ---- PPG
# ---------------------------------  PACCAR INC ---------------------------------
# PG&E CORP ---- PGE4Me
# ---------------------------------  PARKER HANNIFIN CORP ---------------------------------
# ---------------------------------  PENTAIR PLC ---------------------------------
# PEPSICO INC ---- PepsiCo
# APPLIED BIOSYSTEMS ---- thermofisher
# PFIZER INC ---- pfizer
# PFIZER INC ---- pfizer_news
# PFIZER INC ---- Pfizer_UK
# PFIZER INC ---- PfizerEUPolicy
# PFIZER INC ---- PfizerCongress
# PFIZER INC ---- Pfizer_Ireland
# PFIZER INC ---- PfizerNL
# PFIZER INC ---- MylanNews
# CONOCOPHILLIPS ---- conocophillips
# PVH CORP ---- PVHCorp
# PITNEY BOWES ---- PitneyBowes
# PROCTER & GAMBLE ---- ProcterGamble
# PROCTER & GAMBLE ---- PGUK
# PROCTER & GAMBLE ---- pgfrance
# ---------------------------------  PUBLIC SERVICE ENTRP ---------------------------------
# PULTEGROUP INC ---- PulteHomes
# RAYMOND JAMES FINANCIAL ---- RaymondJames
# RAYMOND JAMES FINANCIAL ---- JustinWTSP
# AUTONATION INC ---- CEOMikeJackson
# ROCKWELL AUTOMATION ---- ROKAutomation
# ---------------------------------  ROHM AND HAAS ---------------------------------
# ---------------------------------  ROWANMPANIES ---------------------------------
# ---------------------------------  SAFECO CORP ---------------------------------
# SAFEWAY INC ---- Safeway
# ---------------------------------  SCANA CORP ---------------------------------
# SCHERING PLOUGH ---- Merck
# SHERWIN WILLIAMS CO ---- SherwinWilliams
# ---------------------------------  SIGMA ALDRICH CORP ---------------------------------
# SMITH ---- OfficialWillow
# SMITH ---- RogerCraigSmith
# SMITH ---- bastilledan
# SMITH ---- ThatKevinSmith
# SMITH ---- EmmittSmith22
# SMITH ---- jaden
# SMITH ---- TheJetOnTNT
# SMITH ---- SenTinaSmith
# SMITH ---- TheRealJRSmith
# SMITH ---- TeamJuJu
# SMITH ---- BrianJacobSmith
# SMITH ---- BustaRhymes
# SMITH ---- BradSmi
# SMITH ---- BradleySmith38
# SMITH ---- SenHydeSmith
# SMITH ---- michaelwsmith
# SMITH ---- ememess
# SMITH ---- aetiology
# SMITH ---- TorreySmithWR
# SMITH INTERNATIONAL ---- SydneyAirport
# SMITH INTERNATIONAL ---- benyt
# SMITH INTERNATIONAL ---- thewilbursmith
# SMITH INTERNATIONAL ---- AdamSmithInt
# SMITH INTERNATIONAL ---- jimmysmithmma
# SMITH INTERNATIONAL ---- ewadesmith
# SMITH INTERNATIONAL ---- EmSmithGymnast
# SMITH INTERNATIONAL ---- lewsmith88
# SMUCKER  CO ---- JMSmuckerCo
# SMUCKER  CO ---- Uncrustables
# KEYCORP ---- keybank
# SOUTHERN CO ---- Lauren_Southern
# SOUTHERN CO ---- GMSRailway
# SOUTHERN CO ---- dailyecho
# SOUTHERN CO ---- CSAIRGlobal
# SOUTHERN CO ---- RTCSNV
# SOUTHERN CO ---- SouthernWater
# SOUTHERN CO ---- SMUBasketball
# SOUTHERN CO ---- VALasVegas
# SOUTHERN CO ---- YourSSE
# SOUTHERN CO ---- SUUThunderbirds
# SOUTHWEST AIRLINES ---- SouthwestAir
# SOUTHWEST AIRLINES ---- swapapilots
# AT&T INC ---- ATT
# AT&T INC ---- attcyber
# AT&T INC ---- ItsOnATT
# AT&T INC ---- attJOBS
# AT&T INC ---- github
# AT&T INC ---- AskeBay
# AT&T INC ---- ASUS
# AT&T INC ---- GeneralMills
# AT&T INC ---- frogdesign
# AT&T INC ---- IFTTT
# AT&T INC ---- eBayDealsCanada
# AT&T INC ---- belk
# AT&T INC ---- potatorolls
# AT&T INC ---- payoff
# AT&T INC ---- airtransat
# AT&T INC ---- wwt_inc
# STANLEY BLACK & DECKER ---- StanleyBlkDeckr
# STANLEY BLACK & DECKER ---- BLACKANDDECKER
# STANLEY BLACK & DECKER ---- RamanaGogula
# STATE STREET ---- StateStreet
# STATE STREET ---- StateStreetETFs
# STATE STREET ---- StateStreetGA
# PUBLIC STORAGE ---- PublicStorage
# PUBLIC STORAGE ---- Vultr
# ---------------------------------  NAVIENT CORP ---------------------------------
# SUNTRUST BANKS ---- SunTrust
# ---------------------------------  SUPERVALU INC ---------------------------------
# ---------------------------------  TEMPLE INLAND INC ---------------------------------
# ---------------------------------  TERADYNE INC ---------------------------------
# ANDEAVOR ---- andeavor
# TEXAS INSTRUMENTS ---- TXInstruments
# TEXAS INSTRUMENTS ---- TICalculators
# ---------------------------------  ENERGY FUTURE HOLDINGS ---------------------------------
# TEXTRON INC ---- Textron
# TEXTRON INC ---- EZGOvehicles
# THERMO FISHER SCIENTIFIC ---- thermofisher
# GLOBE LIFE ---- GlobeLifeField
# GLOBE LIFE ---- TIME
# GLOBE LIFE ---- TEXPAMAN
# TRIBUNE MEDIA ---- tribunemedia
# TRIBUNE MEDIA ---- HeraldTribune
# TRIBUNE MEDIA ---- YassTribune
# TRIBUNE MEDIA ---- LauraPavinNews
# TRIBUNE MEDIA ---- TamayoMedia
# TRIBUNE MEDIA ---- PaulSkrbina
# TYCO INTERNATIONAL ---- johnsoncontrols
# TYSON FOODS ---- TysonFoods
# TYSON FOODS ---- TysonFoodsCEO
# TYSON FOODS ---- TysonBrand
# TYSON FOODS ---- kelly_roliard
# ---------------------------------  UNITED AIRLINES HOLDINGS ---------------------------------
# AMEREN CORP ---- AmerenCorp
# UNION PACIFIC ---- UnionPacific
# UNION PACIFIC ---- APALAnational
# UNION PACIFIC ---- sujiseam
# UNITEDHEALTH ---- UnitedHealthGrp
# UNITED PARCEL SERVICE ---- UPS
# RAYTHEON TECHNOLOGIES ---- RaytheonTech
# RAYTHEON TECHNOLOGIES ---- RaytheonPolicy
# RAYTHEON TECHNOLOGIES ---- Raytheon_Jobs
# RAYTHEON TECHNOLOGIES ---- TheHall
# RAYTHEON TECHNOLOGIES ---- UTC
# UNIVERSAL HEALTH ---- CHGlobalHealth
# UNIVERSAL HEALTH ---- WHOMalaysia
# ---------------------------------  VORNADO REALTY TRUST ---------------------------------
# WALMART INC ---- WalmartInc
# WALMART INC ---- Walmart
# WALMART INC ---- rinkisethi
# WALGREENS BOOTS ALLIANCE ---- WBA_Global
# WALGREENS BOOTS ALLIANCE ---- Walgreens
# WALGREENS BOOTS ALLIANCE ---- BootsUK
# WALGREENS BOOTS ALLIANCE ---- BootsHelp
# WALGREENS BOOTS ALLIANCE ---- Boots_Jobs
# WALGREENS BOOTS ALLIANCE ---- fionaortiz
# WENDY'S INTERNATIONAL ---- Wendys
# WENDY'S INTERNATIONAL ---- CaitlinSinett
# WESTERN DIGITAL ---- westerndigital
# WESTERN DIGITAL ---- WDCreators
# WESTERN DIGITAL ---- WesternDigiDC
# WESTERN DIGITAL ---- WesternDigiEdge
# WESTERN DIGITAL ---- AlisonSanders01
# WESTERN DIGITAL ---- wd_black
# WESTERN DIGITAL ---- BerkshireEagle
# ---------------------------------  MEADWESTVACO CORP ---------------------------------
# ---------------------------------  WEYERHAEUSER CO ---------------------------------
# WHIRLPOOL CORP ---- WhirlpoolCorp
# WEC ENERGY ---- aBayraktar1
# ---------------------------------  INTEGRYS HOLDING ---------------------------------
# FOOT LOCKER ---- footlocker
# FOOT LOCKER ---- FootLockerEU
# FOOT LOCKER ---- KidsFootLocker
# FOOT LOCKER ---- FLCCC
# ---------------------------------  XEROX HOLDINGS ---------------------------------
# ---------------------------------  ZIONS BANCORPORATION NA ---------------------------------
# ---------------------------------  BEAR STEARNSMPANIES ---------------------------------
# TRUIST FINANCIAL ---- TruistNews
# NOBLE ---- NobleGG
# NOBLE ---- realrossnoble
# NOBLE ---- BNBuzz
# NOBLE ---- safiyanoble
# NOBLE ---- nookBN
# NOBLE ---- Noble16Mark
# NOBLE ---- YOUNG_NOBLE1
# NOBLE ---- ukinromania
# NOBLE ---- BeNobleSchools
# NOBLE ---- Nobsdaslushhkid
# NOBLE ---- kezia_noble
# ---------------------------------  EMC CORP/MA ---------------------------------
# BIG LOTS ---- BigLots
# MORGAN STANLEY ---- MorganStanley
# MORGAN STANLEY ---- jannarone
# MORGAN STANLEY ---- camcrawford1
# MORGAN STANLEY ---- Thekidstan
# SUN MICROSYSTEMS ---- Oracle
# SUN MICROSYSTEMS ---- alpresnell
# SUN MICROSYSTEMS ---- OracleANZ
# SUN MICROSYSTEMS ---- Oracle_CH
# SUN MICROSYSTEMS ---- larryellison
# PRICE  GROUP ---- TRowePrice
# PRICE  GROUP ---- LazadaMY
# PRICE  GROUP ---- MickPriceRacing
# PRICE  GROUP ---- asda
# MICROSOFT CORP ---- Microsoft
# MICROSOFT CORP ---- MSFTIssues
# MICROSOFT CORP ---- MicrosoftHelps
# MICROSOFT CORP ---- msftsecurity
# MICROSOFT CORP ---- MSFTMechanics
# MICROSOFT CORP ---- msuspartner
# MICROSOFT CORP ---- MicrosoftUK
# MICROSOFT CORP ---- msftsecresponse
# MICROSOFT CORP ---- mslearningcurve
# COTY INC ---- COTYInc
# DIRECTV ---- DIRECTV
# DIRECTV ---- DIRECTVService
# DIRECTV ---- DIRECTVNowHelp
# DIRECTV ---- DIRECTVSports
# DIRECTV ---- DIRECTVServicio
# DIRECTV ---- DIRECTVLA
# DIRECTV ---- DIRECTVChile
# DIRECTV ---- newsmax
# DIRECTV ---- AndrewSiciliano
# DIRECTV ---- DIRECTVEcuador
# DIRECTV ---- DIRECTVCo
# DIRECTV ---- DIRECTVSportsVE
# DIRECTV ---- DIRECTVVE
# DIRECTV ---- OnDIRECTV
# DIRECTV ---- DIRECTVar
# DIRECTV ---- DIRECTVPeru
# DIRECTV ---- directvsportsar
# DIRECTV ---- DIRECTVUy
# ---------------------------------  GENZYME CORP ---------------------------------
# HARLEY DAVIDSON INC ---- harleydavidson
# GARTNER INC ---- Gartner_inc
# GARTNER INC ---- caseylo
# ADOBE INC ---- Adobe
# ADOBE INC ---- yumeakito
# FISERV INC ---- Fiserv
# KB HOME ---- kbhome
# KB HOME ---- Samantha_KB
# KB HOME ---- WNFL
# COCA COLA EUROPEAN PARTNERS ---- CocaColaEP
# ---------------------------------  HARMAN INTERNATIONAL INDS ---------------------------------
# ---------------------------------  AIRGAS INC ---------------------------------
# KRAFT FOODS ---- kraftcheese
# KRAFT FOODS ---- MDLZ
# JOY GLOBAL ---- VDay
# SYNOVUS FINANCIAL ---- synovus
# ---------------------------------  HEALTHPEAK PROPERTIES ---------------------------------
# ---------------------------------  PROGRESSIVE CORP OHIO ---------------------------------
# ---------------------------------  BARR PHARMACEUTICALS ---------------------------------
# ---------------------------------  LEVEL 3MMUNICATIONS ---------------------------------
# ---------------------------------  CARNIVALORATION & ---------------------------------
# TIFFANY & ---- tiffanytunes
# TIFFANY & ---- TiffanyAndCo
# TIFFANY & ---- TiffanyDCross
# TIFFANY & ---- TiffanyHaddish
# TIFFANY & ---- tiffanycli
# TIFFANY & ---- TiffaniThiessen
# TIFFANY & ---- myfabolouslife
# TIFFANY & ---- TiffanyAlvord
# TIFFANY & ---- TiffanyATrump
# TIFFANY & ---- TiffanyTothxoxo
# TIFFANY & ---- tiphayes3
# TIFFANY & ---- tiffanyshlain
# TIFFANY & ---- StalkingGia
# TIFFANY & ---- trsahaydak
# TIFFANY & ---- tiffblackmon
# TIFFANY & ---- TiffanyWeimer
# TIFFANY & ---- Tiffany_Dupont
# TIFFANY & ---- T_Cameron11
# ---------------------------------  ZOETIS INC ---------------------------------
# SCHWAB  CORP ---- CharlesSchwab
# FASTENAL CO ---- FastenalRacing
# ---------------------------------  MAXIM INTEGRATED PRODUCTS ---------------------------------
# FIRST REPUBLIC BANK ---- firstrepublic
# ---------------------------------  ALTERA CORP ---------------------------------
# MGM RESORTS INTERNATIONAL ---- MGMResortsIntl
# MGM RESORTS INTERNATIONAL ---- billhornbuckle
# WASTE MANAGEMENT ---- WasteManagement
# WASTE MANAGEMENT ---- WMPhoenixOpen
# WASTE MANAGEMENT ---- CalRecycle
# WASTE MANAGEMENT ---- SWANA
# DELL TECHNOLOGIES ---- DellTech
# DELL TECHNOLOGIES ---- Dell
# DELL TECHNOLOGIES ---- DellSmallBiz
# DELL TECHNOLOGIES ---- DellMatchPlay
# DELL TECHNOLOGIES ---- DellCares
# DELL TECHNOLOGIES ---- DellEMCServices
# DELL TECHNOLOGIES ---- DellSmbUS
# DELL TECHNOLOGIES ---- DellCaresPRO
# DELL TECHNOLOGIES ---- CareersAtDell
# DELL TECHNOLOGIES ---- DellTechForum
# DELL TECHNOLOGIES ---- DellTechLearn
# DELL TECHNOLOGIES ---- DellTechMEA
# DELL TECHNOLOGIES ---- DellSmbCA
# EW SCRIPPS ---- EWScrippsCo
# OFFICE DEPOT ---- officedepot
# OFFICE DEPOT ---- OfficeDepotMex
# BMC SOFTWARE ---- BMCSoftware
# BMC SOFTWARE ---- BMC_ITSM
# CINCINNATI FINANCIAL ---- CincyTennis
# CINCINNATI FINANCIAL ---- UnitedWayGC
# DEVON ENERGY ---- DevonEnergy
# ---------------------------------  LABORATORY CP OF AMER HLDGS ---------------------------------
# ---------------------------------  FEDERAL HOME LOAN MORTG ---------------------------------
# VALERO ENERGY ---- ValeroEnergy
# STAPLES INC ---- Staples
# ALLERGAN INC ---- meury_bill
# NORTONLIFELOCK INC ---- symantec
# NORTONLIFELOCK INC ---- SymantecASIA
# NORTONLIFELOCK INC ---- SymantecEmail
# NORTONLIFELOCK INC ---- SymantecEMEA
# ABBVIE INC ---- abbvie
# WASHINGTON MUTUAL ---- indiviglio
# ---------------------------------  PEOPLE'S UNITED FINL ---------------------------------
# ELECTRONIC ARTS ---- EA
# ELECTRONIC ARTS ---- EA_Espana
# ELECTRONIC ARTS ---- EASPORTS
# ELECTRONIC ARTS ---- earussia
# ELECTRONIC ARTS ---- EA_Germany
# ELECTRONIC ARTS ---- TheRealAndyMc
# ELECTRONIC ARTS ---- EA_ME
# ELECTRONIC ARTS ---- MattFranchise
# ---------------------------------  COMMERCE BANCORP/NJ ---------------------------------
# SVB FINANCIAL ---- SVB_Financial
# SVB FINANCIAL ---- SVB_UK
# SVB FINANCIAL ---- KateDMitchell
# SVB FINANCIAL ---- dkimerling
# ---------------------------------  SANTANDER HOLDINGS USA ---------------------------------
# ---------------------------------  IQVIA HOLDINGS ---------------------------------
# NEWS CORP ---- newscorp
# NEWS CORP ---- newscorpaus
# NEWS CORP ---- NewsCorpCricket
# NEWS CORP ---- panasonic
# NEWS CORP ---- abcnews
# NEWS CORP ---- visitmusiccity
# NEWS CORP ---- RobertCorp
# NEWS CORP ---- NewsUK
# NEWS CORP ---- superracing
# NEWS CORP ---- CharlesSchwab
# NEWS CORP ---- manilabulletin
# NEWS CORP ---- BurberryCorp
# NEWS CORP ---- billbirtles
# NEWS CORP ---- CanonUSA
# NEWS CORP ---- DynCorpIntl
# NEWS CORP ---- BofA_News
# ---------------------------------  MALLINCKRODT PLC ---------------------------------
# PTC INC ---- PTC
# TWITTER INC ---- Twitter
# TWITTER INC ---- TwitterData
# TWITTER INC ---- WWE
# TWITTER INC ---- SEGA
# TWITTER INC ---- INCIndia
# TWITTER INC ---- amazon
# TWITTER INC ---- acnnews
# TWITTER INC ---- GoPro
# TWITTER INC ---- WWEUniverse
# TWITTER INC ---- MarvelMusicInc
# TWITTER INC ---- MarvelUK
# TWITTER INC ---- amazonIN
# TWITTER INC ---- CanonUSA
# TWITTER INC ---- blockbuster
# TWITTER INC ---- ASUS
# TWITTER INC ---- Stussy
# TWITTER INC ---- InterFM897
# TWITTER INC ---- HondaCanada
# TWITTER INC ---- ANSYS
# CAESARS ENTERTAINMENT ---- CaesarsEnt
# CAESARS ENTERTAINMENT ---- Caesars_Rewards
# CABOT OIL & GAS ---- CabotOG
# ---------------------------------  DENBURY RESOURCES ---------------------------------
# SYNCHRONY FINANCIAL ---- synchrony
# ARISTA NETWORKS ---- AristaNetworks
# CISCO SYSTEMS ---- Cisco
# CISCO SYSTEMS ---- CiscoCollab
# CISCO SYSTEMS ---- CiscoLive
# CISCO SYSTEMS ---- CiscoNetworking
# CISCO SYSTEMS ---- CiscoPartners
# CISCO SYSTEMS ---- ciscoDC
# CISCO SYSTEMS ---- LearningatCisco
# CISCO SYSTEMS ---- CiscoPress
# CISCO SYSTEMS ---- HeyCisco
# CISCO SYSTEMS ---- CiscoIT
# CISCO SYSTEMS ---- CiscoNetAcad
# CISCO SYSTEMS ---- cisco_in
# CISCO SYSTEMS ---- MarkPhibbs
# CITIZENS FINANCIAL ---- CitizensBank
# CITIZENS FINANCIAL ---- CFGCommercial
# CITIZENS FINANCIAL ---- CEFCU
# CITIZENS FINANCIAL ---- CFG_Newsroom
# CITIZENS FINANCIAL ---- citylordmayor
# CITIZENS FINANCIAL ---- TCAuditor
# ---------------------------------  ALLIED WASTE INDUSTRIES ---------------------------------
# HCA HEALTHCARE ---- HCAhealthcare
# XILINX INC ---- XilinxInc
# ---------------------------------  BAXALTA INC ---------------------------------
# REGENERON PHARMACEUTICALS ---- Regeneron
# ---------------------------------  PMC SIERRA INC ---------------------------------
# ---------------------------------  CEPHALON INC ---------------------------------
# UNITED STATES STEEL ---- dennisogbe
# JONES ---- OwenJones84
# JONES ---- KySportsRadio
# JONES ---- actordougjones
# JONES ---- ManMadeMoon
# JONES ---- Lesdoggg
# JONES ---- DowJones
# JONES ---- JonnyBones
# JONES ---- MotherJones
# JONES ---- luciejones1
# JONES ---- RealCJ10
# JONES ---- Nas
# JONES ---- RealSirTomJones
# JONES ---- themiltonjones
# JONES ---- curtisjr_10
# JONES ---- Byron31Jump
# JONES ---- JessicaJones
# JONES ---- theferocity
# JONES ---- nhannahjones
# JONES ---- VinnieJones65
# ---------------------------------  AMBAC FINANCIAL ---------------------------------
# MONSTER BEVERAGE ---- MonsterEnergy
# XL LTD ---- qikipedia
# VERTEX PHARMACEUTICALS ---- VertexPharma
# ---------------------------------  MGIC INVESTMENT/WI ---------------------------------
# BIOGEN INC ---- biogen
# PAYPAL HOLDINGS ---- PayPal
# PAYPAL HOLDINGS ---- PayPalUK
# PERRIGO ---- billyperrigo
# QUALCOMM INC ---- Qualcomm
# QUALCOMM INC ---- QualcommVenture
# GILEAD SCIENCES ---- GileadSciences
# WHOLE FOODS MARKET ---- WholeFoods
# WHOLE FOODS MARKET ---- 365byWholeFoods
# ---------------------------------  ROPER TECHNOLOGIES ---------------------------------
# SYNOPSYS INC ---- SW_Integrity
# TIME WARNER ---- SportsNetLA
# TIME WARNER ---- SpectrumSN
# TIME WARNER ---- Mike_Bresnahan
# TIME WARNER ---- spectrumcenter
# TIME WARNER ---- EatFellowHumans
# TIME WARNER ---- DavidKris
# TIME WARNER ---- smileybridge
# TIME WARNER ---- AOL
# TIME WARNER ---- atari
# LINDE PLC ---- Lindeplc
# FIRST DATA ---- IndiaSpend
# FIRST DATA ---- Fiserv
# FIRST DATA ---- Quantcast
# BOSTON SCIENTIFIC ---- bostonsci
# BOSTON SCIENTIFIC ---- AIRWorldwide
# ---------------------------------  KOHL'S CORP ---------------------------------
# BED BATH & BEYOND ---- BedBathBeyond
# D R HORTON ---- DRHorton
# EXPRESS SCRIPTS HOLDING ---- ExpressScripts
# STARBUCKS CORP ---- Starbucks
# STARBUCKS CORP ---- StarbucksMY
# STARBUCKS CORP ---- SbuxIndonesia
# STARBUCKS CORP ---- Starbucks_J
# ---------------------------------  COMPUWARE CORP ---------------------------------
# HEWLETT PACKARD ENTERPRISE ---- HPE
# HEWLETT PACKARD ENTERPRISE ---- AntonioNeri_HPE
# HEWLETT PACKARD ENTERPRISE ---- CoffeeCoaching
# HEWLETT PACKARD ENTERPRISE ---- HPE_APAC
# HEWLETT PACKARD ENTERPRISE ---- HPE_IN
# HEWLETT PACKARD ENTERPRISE ---- HPE_Careers
# HEWLETT PACKARD ENTERPRISE ---- HPE_UKI
# CSRA INC ---- CSRA_inc
# ---------------------------------  FOURRNERS PROPERTY TR ---------------------------------
# ---------------------------------  INGEVITY CORP ---------------------------------
# ADIENT PLC ---- Adient
# ALLERGAN PLC ---- brentlsaunders
# ALLERGAN PLC ---- meury_bill
# HUMANA INC ---- Humana
# HUMANA INC ---- HumanaHelp
# INTUIT INC ---- rinkisethi
# MICROCHIP TECHNOLOGY ---- MicrochipTech
# ---------------------------------  ADVANSIX INC ---------------------------------
# FOSSIL ---- Fossil
# FOSSIL ---- fossilenergygov
# FOSSIL ---- JDFossilBedsNPS
# FOSSIL ---- FlorissantNPS
# ---------------------------------  BROOKFIELD PROPERTY REIT ---------------------------------
# O'REILLY AUTOMOTIVE ---- oreillyauto
# ROYAL CARIBBEAN CRUISES LTD ---- CelebrityCruise
# ---------------------------------  PETSMART INC ---------------------------------
# ---------------------------------  LAMB WESTON HOLDINGS ---------------------------------
# KEURIG DR PEPPER ---- GreenMtnCoffee
# MARRIOTT ---- Marriott
# MARRIOTT ---- MarriottIntl
# MARRIOTT ---- ACHotels
# MARRIOTT ---- FairfieldHotels
# MARRIOTT ---- MarriottVacClub
# MARRIOTT ---- CourtyardHotels
# MARRIOTT ---- MarriottResorts
# MARRIOTT ---- LondonMarriott
# MARRIOTT ---- ResidenceInn
# MARRIOTT ---- MarriottBonvoy
# MARRIOTT ---- MarriottCareers
# MARRIOTT ---- JamesMarriottYT
# MARRIOTT ---- MBonvoyAssist
# MARRIOTT ---- JaneMarriottUK
# ---------------------------------  INCYTE CORP ---------------------------------
# URBAN OUTFITTERS ---- UrbanOutfitters
# URBAN OUTFITTERS ---- uoeurope
# URBAN OUTFITTERS ---- uofrance
# URBAN OUTFITTERS ---- UODeutschland
# ---------------------------------  CARS.COM INC ---------------------------------
# SIMON PROPERTY ---- _simonlambert
# EASTMAN CHEMICAL ---- EastmanChemCo
# ---------------------------------  MID AMERICA APT CMNTYS ---------------------------------
# ---------------------------------  QLOGIC CORP ---------------------------------
# ---------------------------------  BIOVERATIV INC ---------------------------------
# ---------------------------------  WESTROCK CO ---------------------------------
# ---------------------------------  AVALONBAYMMUNITIES ---------------------------------
# ---------------------------------  AK STEEL HOLDING ---------------------------------
# ---------------------------------  PROLOGIS INC ---------------------------------
# ---------------------------------  LEHMAN BROTHERS HOLDINGS ---------------------------------
# ---------------------------------  APARTMENT INVST & MGMT ---------------------------------
# ---------------------------------  AFFILIATEDMPUTER SERVICES ---------------------------------
# ---------------------------------  REALTYOME ---------------------------------
# ---------------------------------  TECHNIPFMC PLC ---------------------------------
# CAPITAL ONE FINANCIAL ---- CapitalOne
# CAPITAL ONE FINANCIAL ---- RelianceCapital
# CAPITAL ONE FINANCIAL ---- CityPortland
# APOLLO EDUCATION ---- ApolloTheater
# ---------------------------------  BRIGHTHOUSE FINANL ---------------------------------
# DARDEN RESTAURANTS ---- darden
# BAKER HUGHES ---- Avitas_Systems
# ---------------------------------  JBG SMITH PPTYS ---------------------------------
# ---------------------------------  CHAMPIONX CORP ---------------------------------
# PERSPECTA INC ---- Perspecta
# DOW INC ---- DowNewsroom
# DOW INC ---- DowPackaging
# DOW INC ---- DuPont_News
# FOX CORP ---- newscorp
# FOX CORP ---- 20thcentury
# FOX CORP ---- FoxResponse
# FOX CORP ---- DaveRic1
# KONTOOR BRANDS ---- KontoorBrands
# CORTEVA INC ---- corteva
# CORTEVA INC ---- CortevaUS
# CORTEVA INC ---- CortevaCA
# CAMERON INTERNATIONAL ---- cameron_tiff
# DISH NETWORK ---- dish_answers
# DISH NETWORK ---- CBSSportsNet
# DISH NETWORK ---- carriesheffield
# DISH NETWORK ---- freespeechtv
# DISH NETWORK ---- DishMx
# ---------------------------------  SUNEDISON INC ---------------------------------
# ---------------------------------  EVEREST RE LTD ---------------------------------
# ---------------------------------  DIAMOND OFFSHRE DRILLING ---------------------------------
# DAVITA INC ---- DaVita
# ---------------------------------  QWESTMMUNICATION ---------------------------------
# HENRY SCHEIN ---- HenrySchein
# ---------------------------------  SANDISK CORP ---------------------------------
# WATERS CORP ---- WatersCorp
# NETAPP INC ---- NetApp
# NETAPP INC ---- NetAppME
# NETAPP INC ---- NetAppEMEA
# NETAPP INC ---- NetAppANZ
# NETAPP INC ---- NetAppAPAC
# NETAPP INC ---- NetAppSchweiz
# NETAPP INC ---- NetAppAustria
# NETAPP INC ---- NetAppFrance
# CITRIX SYSTEMS ---- citrix
# CITRIX SYSTEMS ---- tminahan
# CITRIX SYSTEMS ---- DavidJHenshall
# HARTFORD FINANCIAL SERVICES ---- TheHartford
# ALEXION PHARMACEUTICALS ---- AlexionPharma
# ALTABA INC ---- Yahoo
# ALTABA INC ---- YahooSG
# DEAN FOODS ---- TysonFoodsCEO
# ANSYS INC ---- ANSYS
# E TRADE FINANCIAL ---- etrade
# ABERCROMBIE & FITCH ---- Abercrombie
# ABERCROMBIE & FITCH ---- AbercrombieHelp
# ABERCROMBIE & FITCH ---- abercrombiekids
# ENDO INTERNATIONAL ---- TheLancetEndo
# ---------------------------------  UNIVISIONMMUNICATIONS ---------------------------------
# ---------------------------------  IMS HEALTH HOLDINGS ---------------------------------
# NATIONAL OILWELL VARCO ---- NOVGlobal
# MONSTER WORLDWIDE ---- MonsterWW
# MONSTER WORLDWIDE ---- Monster
# MONSTER WORLDWIDE ---- MonsterGaming
# QUEST DIAGNOSTICS ---- QuestDX
# ---------------------------------  CIENA CORP ---------------------------------
# ---------------------------------  TAKE TWO INTERACTIVE SFTWR ---------------------------------
# AMAZON.COM INC ---- AmazonHelp
# AMAZON.COM INC ---- amazon
# AMAZON.COM INC ---- amazonIN
# AMAZON.COM INC ---- AmazonUK
# AMAZON.COM INC ---- amazonnews
# AMAZON.COM INC ---- amazon_policy
# ---------------------------------  ALEXANDRIA R E EQUITIES ---------------------------------
# RALPH LAUREN ---- RalphLauren
# RALPH LAUREN ---- nachofigueras
# RALPH LAUREN ---- kohliseetu
# RALPH LAUREN ---- seetukohlihome
# BOSTON PROPERTIES ---- PeterSouhleris
# YUM BRANDS ---- yumbrands
# YUM BRANDS ---- FoodBlogs
# UNITED RENTALS ---- UnitedRentals
# VERISIGN INC ---- VERISIGN
# ---------------------------------  BROADCOM CORP ---------------------------------
# ---------------------------------  AMCOR PLC ---------------------------------
# NIELSEN HOLDINGS ---- nielsen
# ---------------------------------  NORWEGIAN CRUISE LINE HLDGS ---------------------------------
# REPUBLIC SERVICES ---- RepublicService
# REPUBLIC SERVICES ---- familyandlabour
# REPUBLIC SERVICES ---- GovernmentZA
# REPUBLIC SERVICES ---- MoH_Somalia
# EBAY INC ---- eBay
# EBAY INC ---- AskeBay
# EBAY INC ---- eBayNewsroom
# EBAY INC ---- eBay4CharityUS
# EBAY INC ---- eBay_UK
# EBAY INC ---- eBayForBusiness
# EBAY INC ---- eBayCanada
# EBAY INC ---- eBayDealsCanada
# EBAY INC ---- eBayAU
# EBAY INC ---- ebaytech
# EBAY INC ---- ebaymainstreet
# EBAY INC ---- ryanspoon
# EBAY INC ---- eBayDE_News
# EBAY INC ---- rinkisethi
# GOLDMAN SACHS ---- GoldmanSachs
# GOLDMAN SACHS ---- marcus_uk
# GOLDMAN SACHS ---- marcus
# GOLDMAN SACHS ---- GSCareers
# GOLDMAN SACHS ---- MarkTercek
# GOLDMAN SACHS ---- samgrobart
# GOLDMAN SACHS ---- GS10KWomen
# GOLDMAN SACHS ---- GS10KSmallBiz
# NVIDIA CORP ---- nvidia
# APTIV PLC ---- Aptiv
# LIFE TECHNOLOGIES ---- Skype
# LIFE TECHNOLOGIES ---- SlackHQ
# LIFE TECHNOLOGIES ---- CareersAtDell
# LIFE TECHNOLOGIES ---- InfosysCareers
# LIFE TECHNOLOGIES ---- PKILifeScience
# BOOKING HOLDINGS ---- BookingHoldings
# ---------------------------------  CNX RESOURCESORATION ---------------------------------
# REYNOLDS AMERICAN ---- coreyreynoldsLA
# ---------------------------------  SBAMMUNICATIONS ---------------------------------
# JUNIPER NETWORKS ---- JuniperNetworks
# JUNIPER NETWORKS ---- Juniper_UK
# JUNIPER NETWORKS ---- Juniper_FR
# JUNIPER NETWORKS ---- ramirahim
# JUNIPER NETWORKS ---- Juniper_DE
# JUNIPER NETWORKS ---- Juniper_Japan
# ---------------------------------  HUDSON CITY BANCORP ---------------------------------
# RED HAT ---- RedHat
# RED HAT ---- RedHatGov
# RED HAT ---- RedHatPartners
# BLACKROCK INC ---- blackrock
# AKAMAI TECHNOLOGIES ---- Akamai
# ---------------------------------  CHARTERMMUNICATIONS ---------------------------------
# EXPEDIA ---- Expedia
# EXPEDIA ---- ExpediaGroup
# EXPEDIA ---- ExpediaCA
# EXPEDIA ---- ExpediaIE
# EXPEDIA ---- expediapartners
# EXPEDIA ---- expedia_au
# EXPEDIA ---- ExpediaUK
# EXPEDIA ---- expedia_nz
# EXPEDIA ---- Expedia_Japan
# AGILENT TECHNOLOGIES ---- AgilentChem
# EDWARDS LIFESCIENCES ---- EdwardsLifesci
# ---------------------------------  METLIFE INC ---------------------------------
# ---------------------------------  FRONTIERMMUNICATIONS ---------------------------------
# NRG ENERGY ---- nrgenergy
# ILLUMINA INC ---- illumina
# ILLUMINA INC ---- pschiller
# TAPESTRY INC ---- Coach
# GARMIN LTD ---- Garmin
# GLOBAL PAYMENTS ---- VisaNews
# GLOBAL PAYMENTS ---- DiscoverGlobal
# GLOBAL PAYMENTS ---- Blackhawk
# PEABODY ENERGY ---- peabodyenergy
# MONDELEZ INTERNATIONAL ---- MDLZ
# MONDELEZ INTERNATIONAL ---- DanaAnderson
# PRUDENTIAL FINANCIAL ---- Prudential
# PRUDENTIAL FINANCIAL ---- APRAinfo
# PRUDENTIAL FINANCIAL ---- ICICIPruLife
# PRUDENTIAL FINANCIAL ---- Salene
# PRUDENTIAL FINANCIAL ---- pgim
# PRUDENTIAL FINANCIAL ---- BradfordHearn
# WILLIS TOWERS WATSON ---- WTWesp
# ANTHEM INC ---- AnthemInc
# GAMESTOP CORP ---- gamestopcorp
# ---------------------------------  CENTENE CORP ---------------------------------
# PRINCIPAL FINANCIAL ---- principal
# PRINCIPAL FINANCIAL ---- sidbiofficial
# NETFLIX INC ---- netflix
# NETFLIX INC ---- NetflixUK
# NETFLIX INC ---- NetflixFilm
# NETFLIX INC ---- NetflixANZ
# NETFLIX INC ---- Netflixhelps
# NETFLIX INC ---- Netflix_PH
# NETFLIX INC ---- netflixfamily
# NETFLIX INC ---- NetflixNordic
# NETFLIX INC ---- contodonetflix
# NETFLIX INC ---- NetflixLAT
# NETFLIX INC ---- NetflixFR
# NETFLIX INC ---- NetflixBrasil
# NETFLIX INC ---- NetflixJP
# NETFLIX INC ---- NetflixJP_Anime
# NETFLIX INC ---- NetflixMENA
# NETFLIX INC ---- NetflixES
# NETFLIX INC ---- NetflixPT
# ---------------------------------  TRANSDIGM ---------------------------------
# CME ---- CMEGroup
# CME ---- MDHHS_CME
# CME ---- MedscapeCME
# CME ---- CMEActiveTrader
# ---------------------------------  WYNN RESORTS LTD ---------------------------------
# NASDAQ INC ---- Broadcom
# NASDAQ INC ---- Fiserv
# NASDAQ INC ---- HenrySchein
# NASDAQ INC ---- USFunds
# CIT ---- Canberra_CIT
# CIT ---- CitImmCanada
# CIT ---- FedCitSci
# CIT ---- MCNocando
# CIT ---- CitAdviceScot
# CIT ---- IMA_CitRights
# CIT ---- NatCitAlliance
# CIT ---- CitSciBio
# SEAGATE TECHNOLOGY ---- Seagate
# ---------------------------------  QEP RESOURCES ---------------------------------
# ---------------------------------  ASSURANT INC ---------------------------------
# SALESFORCE.COM INC ---- salesforce
# SALESFORCE.COM INC ---- SalesforceOrg
# SALESFORCE.COM INC ---- SalesforceEng
# SALESFORCE.COM INC ---- SalesforceNews
# GENWORTH FINANCIAL ---- Genworth
# ---------------------------------  MARKETAXESS HOLDINGS ---------------------------------
# ---------------------------------  HOSPIRA INC ---------------------------------
# ---------------------------------  METROPCSMMUNICATIONS ---------------------------------
# EXTRA SPACE STORAGE ---- extraspace
# DIGITAL REALTY TRUST ---- DigitalAPAC
# MOSAIC CO ---- SuttonBStracke
# INTERCONTINENTAL EXCHANGE ---- BettyWLiu
# INTERCONTINENTAL EXCHANGE ---- ICEHousePodcast
# ---------------------------------  CF INDUSTRIES HOLDINGS ---------------------------------
# DISCOVERY INC ---- DiscoveryIncTV
# DISCOVERY INC ---- Discovery
# DISCOVERY INC ---- Discovery_Mx
# DISCOVERY INC ---- DiscoveryMENA
# AMERIPRISE FINANCIAL ---- ameriprise
# UNDER ARMOUR ---- UnderArmour
# UNDER ARMOUR ---- UAbasketball
# UNDER ARMOUR ---- UAFootball
# UNDER ARMOUR ---- UAWomen
# UNDER ARMOUR ---- UAGolf
# UNDER ARMOUR ---- UAnews
# UNDER ARMOUR ---- AskTeamUA
# UNDER ARMOUR ---- natashahastings
# UNDER ARMOUR ---- ToddDurkin
# UNDER ARMOUR ---- tj_athlete
# ---------------------------------  LEIDOS HOLDINGS ---------------------------------
# CHIPOTLE MEXICAN GRILL ---- ChipotleTweets
# CHIPOTLE MEXICAN GRILL ---- ChipotleUK
# CHIPOTLE MEXICAN GRILL ---- ChipotleJobs
# CHIPOTLE MEXICAN GRILL ---- ChipotleFR
# ---------------------------------  FIDELITY NATIONAL INFO ---------------------------------
# NYSE EURONEXT ---- artmarketdotcom
# NYSE EURONEXT ---- nokia
# FACEBOOK INC ---- fbnewsroom
# FACEBOOK INC ---- Facebook
# FACEBOOK INC ---- facebookapp
# FACEBOOK INC ---- RazerSupport
# FACEBOOK INC ---- Alden_Gonzalez
# FACEBOOK INC ---- SimonPearceInc
# FACEBOOK INC ---- hemeon
# FACEBOOK INC ---- wa_status
# ---------------------------------  DIAMONDBACK ENERGY ---------------------------------
# PHILLIPS 66 ---- Phillips66Co
# PHILLIPS 66 ---- Phillips66Gas
# ---------------------------------  EMBARQ CORP ---------------------------------
# WINDSTREAM HOLDINGS ---- Windstream
# WYNDHAM DESTINATIONS ---- wyndestinations
# WESTERN UNION ---- WesternUnion
# WESTERN UNION ---- WesternUnionCEO
# WESTERN UNION ---- wucanada
# WESTERN UNION ---- UnionPacific
# WESTERN UNION ---- WGAWest
# WESTERN UNION ---- WUBusiness
# WESTERN UNION ---- MikeValdesFauli
# WESTERN UNION ---- WUStopFraud
# TIME WARNER CABLE ---- SpectrumSN
# TIME WARNER CABLE ---- SportsNetLA
# TIME WARNER CABLE ---- Mike_Bresnahan
# TIME WARNER CABLE ---- spectrumcenter
# ---------------------------------  BROADRIDGE FINANCIAL SOLUTNS ---------------------------------
# ---------------------------------  COVIDIEN PLC ---------------------------------
# ---------------------------------  TENNECTIVITY LTD ---------------------------------
# DISCOVER FINANCIAL ---- Discover
# MSCI INC ---- MSCI_Inc
# ULTA BEAUTY ---- ultabeauty
# AMERICAN WATER WORKS ---- amwater
# VISA INC ---- Visa
# VISA INC ---- VisaUK
# VISA INC ---- VisaSecurity
# VISA INC ---- RushCard
# PHILIP MORRIS INTERNATIONAL ---- InsidePMI
# PHILIP MORRIS INTERNATIONAL ---- DrGilchrist
# DR PEPPER SNAPPLE ---- DrPepperSnapple
# ACTIVISION BLIZZARD ---- ATVI_AB
# ACTIVISION BLIZZARD ---- Activision
# ACTIVISION BLIZZARD ---- pellesjoenell
# ACTIVISION BLIZZARD ---- BobbyKotick
# ACTIVISION BLIZZARD ---- PeteVlastelica
# ACTIVISION BLIZZARD ---- Cameron__Lee
# BROADCOM INC ---- Broadcom
# BROADCOM INC ---- symantec
# BROADCOM INC ---- SymantecEMEA
# BROADCOM INC ---- SymantecASIA
# BROADCOM INC ---- SymantecEmail
# BROADCOM INC ---- Brocade
# BROADCOM INC ---- CAinc
# BROADCOM INC ---- CA_IM
# ---------------------------------  CAREFUSION CORP ---------------------------------
# FORTINET INC ---- Fortinet
# CBOE GLOBAL MARKETS ---- BatsGlobal
# ---------------------------------  FLEETCOR TECHNOLOGIES ---------------------------------
# ---------------------------------  MOTOROLA MOBILITY HLDGS ---------------------------------
# ---------------------------------  HUNTINGTON INGALLS IND ---------------------------------
# MARATHON PETROLEUM ---- MarathonPetroCo
# ---------------------------------  WPX ENERGY ---------------------------------
# ---------------------------------  FORTUNE BRANDS HOME & SECUR ---------------------------------
# ---------------------------------  CAPRI HOLDINGS LTD ---------------------------------
# TRIPADVISOR INC ---- TripAdvisor
# CBRE ---- CBRE
# CBRE ---- CBREAmericas
# CBRE ---- CBREHongKong
# CBRE ---- CBREThailand
# CBRE ---- cbreasia
# CBRE ---- CBRESingapore
# CBRE ---- CBRE_UK
# CBRE ---- cbreNewZealand
# CBRE ---- CBRESoCal
# CBRE ---- CBREResearch
# CBRE ---- CBREDFW
# CBRE ---- cbreAustralia
# CBRE ---- cbrechicago
# CBRE ---- CBRE_India
# ---------------------------------  LYONDELLBASELL INDUSTRIES NV ---------------------------------

# %%
columns = ['GVKEY', 'Company', 'Handle', 'Twitter_Descr', 'verified']
tdf = pd.DataFrame(list(zip(gvk, companies, handles, descriptions, verified)), columns =columns) 
tdf.dropna(inplace=True)
tdf= tdf[tdf['verified']!=False]
tdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1304 entries, 0 to 1303
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GVKEY          1304 non-null   int64
#  1   Company        1304 non-null   object
#  2   Handle         1304 non-null   object
#  3   Twitter_Descr  1304 non-null   object
#  4   verified       1304 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 52.2+ KB

# %%
tdf['Company'].value_counts()[:60]
# Out:
# JOHNSON & JOHNSON               19
# JONES GROUP INC                 19
# SMITH (A.O.)                    19
# TWITTER INC                     19
# NEW YORK TIMES CO  -CL A        19
# TIFFANY & CO                    18
# COCA-COLA CO                    18
# DIRECTV                         18
# NETFLIX INC                     17
# AT&T INC                        16
# BANK OF AMERICA CORP            16
# NEWS CORP                       16
# LILLY (ELI) & CO                15
# EXXON MOBIL CORP                14
# MARRIOTT INTL INC               14
# CBRE GROUP INC                  14
# EBAY INC                        14
# EATON CORP PLC                  13
# MCCORMICK & CO INC              13
# DISNEY (WALT) CO                13
# CISCO SYSTEMS INC               13
# DELL TECHNOLOGIES INC           13
# AMERICAN EXPRESS CO             12
# GENERAL MOTORS CO               11
# LINCOLN NATIONAL CORP           11
# NOBLE CORP PLC                  11
# GENERAL ELECTRIC CO             11
# FORD MOTOR CO                   11
# LOCKHEED MARTIN CORP            11
# BEST BUY CO INC                 10
# UNDER ARMOUR INC                10
# EL PASO CORP                    10
# SOUTHERN CO                     10
# NORTHERN TRUST CORP             10
# AMERICAN INTERNATIONAL GROUP    10
# GENERAL DYNAMICS CORP            9
# TIME WARNER INC                  9
# JPMORGAN CHASE & CO              9
# CVS HEALTH CORP                  9
# MICROSOFT CORP                   9
# WELLS FARGO & CO                 9
# EXPEDIA GROUP INC                9
# S&P GLOBAL INC                   9
# SMITH INTERNATIONAL INC          8
# CIT GROUP INC                    8
# PFIZER INC                       8
# GOLDMAN SACHS GROUP INC          8
# M & T BANK CORP                  8
# NATIONAL CITY CORP               8
# WESTERN UNION CO                 8
# FACEBOOK INC                     8
# MERCK & CO                       8
# KELLOGG CO                       8
# ELECTRONIC ARTS INC              8
# BROADCOM INC                     8
# NETAPP INC                       8
# WESTERN DIGITAL CORP             7
# HEWLETT PACKARD ENTERPRISE       7
# PRUDENTIAL FINANCIAL INC         6
# ACTIVISION BLIZZARD INC          6
# Name: Company, dtype: int64

# %%
dfs=tdf[tdf['Company'].map(tdf['Company'].value_counts()) > 1]
dfs.Company.value_counts()
# Out:
# JONES GROUP INC             19
# NEW YORK TIMES CO  -CL A    19
# JOHNSON & JOHNSON           19
# TWITTER INC                 19
# SMITH (A.O.)                19
#                             ..
# ALASKA AIR GROUP INC         2
# ALTABA INC                   2
# QUALCOMM INC                 2
# EMERSON ELECTRIC CO          2
# BRISTOL-MYERS SQUIBB CO      2
# Name: Company, Length: 193, dtype: int64

# %%
# w/o string corrections
# 666 handles
# 299 badnames
# 264 verified handles

# %%
len(badnames)
# Out:
# 153

# %%
len(tdf.Company.unique())
# Out:
# 371

# %%
import os
os.getcwd()
# Out:
# 'D:\\OneDrive - Indian School of Business\\Projects\\Mindset\\tweets\\TWITTERHANDLESSEARCH\\code'

# %%
dfb= pd.DataFrame(list(zip(badgv, badnames)), columns =['GVKEY', 'Company'])

dfb.to_csv('../kashish files/output/Bad Names/badnames_tweepy.csv', index=False)
dfb
# Out:
#       GVKEY                       Company
# 0      1013    ADC TELECOMMUNICATIONS INC
# 1      1075    PINNACLE WEST CAPITAL CORP
# 2      1318                   ALLTEL CORP
# 3      1449                     AFLAC INC
# 4      1661         NABORS INDUSTRIES LTD
# ..      ...                           ...
# 148  186310    HUNTINGTON INGALLS IND INC
# 149  187128                WPX ENERGY INC
# 150  188255   FORTUNE BRANDS HOME & SECUR
# 151  198058            CAPRI HOLDINGS LTD
# 152  294524  LYONDELLBASELL INDUSTRIES NV
#
# [153 rows x 2 columns]

# %%
dfb1=pd.read_csv('../kashish files/output/Bad Names/badnames_gsearch.csv')

# %%
bdf= pd.concat([dfb, dfb1], axis=0)
bdf
# Out:
#       GVKEY                       Company
# 0      1013    ADC TELECOMMUNICATIONS INC
# 1      1075    PINNACLE WEST CAPITAL CORP
# 2      1318                   ALLTEL CORP
# 3      1449                     AFLAC INC
# 4      1661         NABORS INDUSTRIES LTD
# ..      ...                           ...
# 110  186310        HUNTINGTON INGALLS IND
# 111  187128                    WPX ENERGY
# 112  188255   FORTUNE BRANDS HOME & SECUR
# 113  198058            CAPRI HOLDINGS LTD
# 114  294524  LYONDELLBASELL INDUSTRIES NV
#
# [268 rows x 2 columns]

# %%
bdf.drop_duplicates(subset='GVKEY',inplace=True)
bdf.shape
# Out:
# (115, 2)

# %%
bdf= bdf[~bdf.Company.isin(gs)]
bdf= bdf[~bdf.Company.isin(ts)]
bdf
# Out:
#       GVKEY                       Company
# 0      1013    ADC TELECOMMUNICATIONS INC
# 1      1075    PINNACLE WEST CAPITAL CORP
# 2      1318                   ALLTEL CORP
# 3      1661         NABORS INDUSTRIES LTD
# 4      1794   ASHLAND GLOBAL HOLDINGS INC
# ..      ...                           ...
# 110  186310    HUNTINGTON INGALLS IND INC
# 111  187128                WPX ENERGY INC
# 112  188255   FORTUNE BRANDS HOME & SECUR
# 113  198058            CAPRI HOLDINGS LTD
# 114  294524  LYONDELLBASELL INDUSTRIES NV
#
# [115 rows x 2 columns]

# %%
bdf.Company.value_counts()
# Out:
# LEHMAN BROTHERS HOLDINGS INC    1
# SBA COMMUNICATIONS CORP         1
# HUNTINGTON INGALLS IND INC      1
# COVIDIEN PLC                    1
# BAXALTA INC                     1
#                                ..
# BROADRIDGE FINANCIAL SOLUTNS    1
# AFFILIATED COMPUTER SERVICES    1
# CENTENE CORP                    1
# MAXIM INTEGRATED PRODUCTS       1
# TEMPLE-INLAND INC               1
# Name: Company, Length: 115, dtype: int64

# %%
bdf.reset_index(inplace=True)
bdf.drop(['index'], axis=1, inplace=True)

# %%
bdf
# Out:
#       GVKEY                       Company
# 0      1013    ADC TELECOMMUNICATIONS INC
# 1      1075    PINNACLE WEST CAPITAL CORP
# 2      1318                   ALLTEL CORP
# 3      1661         NABORS INDUSTRIES LTD
# 4      1794   ASHLAND GLOBAL HOLDINGS INC
# ..      ...                           ...
# 110  186310    HUNTINGTON INGALLS IND INC
# 111  187128                WPX ENERGY INC
# 112  188255   FORTUNE BRANDS HOME & SECUR
# 113  198058            CAPRI HOLDINGS LTD
# 114  294524  LYONDELLBASELL INDUSTRIES NV
#
# [115 rows x 2 columns]

# %%
list_dfs=[bdf.iloc[:19], bdf.iloc[19:38], bdf.iloc[38:57], bdf.iloc[57:76], bdf.iloc[76:95], bdf.iloc[95:]]
xls_path= r"D:\OneDrive - Indian School of Business\Data\badnames.xlsx"

# %%
def save_xls(list_dfs, xls_path):
    with pd.ExcelWriter(xls_path) as writer:
        for n, df in enumerate(list_dfs):
            df.to_excel(writer,'sheet%s' % n)
        writer.save()

# %%
save_xls(list_dfs, xls_path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xlsxwriter\workbook.py:329: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
bdf.iloc[:19].to_excel('badnames.xlsx', sheet_name='Prof')
bdf.iloc[19:38].to_excel('badnames.xlsx', sheet_name='Sachin')
bdf.iloc[38:57].to_excel('badnames.xlsx', sheet_name='Kashish')
bdf.iloc[57:76].to_excel('badnames.xlsx', sheet_name='Prashanth')
bdf.iloc[76:95].to_excel('badnames.xlsx', sheet_name='Palkit')
bdf.iloc[95:].to_excel('badnames.xlsx', sheet_name='Richa')

# %%
badnames
# Out:
# ['ADC TELECOMMUNICATIONS INC',
#  'PINNACLE WEST CAPITAL CORP',
#  'ALLTEL CORP',
#  'AFLAC INC',
#  'NABORS INDUSTRIES LTD',
#  'ANHEUSER-BUSCH COS INC',
#  'ASHLAND GLOBAL HOLDINGS INC',
#  'UNISYS CORP',
#  'CIGNA CORP',
#  'CSX CORP',
#  'CENTURYLINK INC',
#  'CIRCUIT CITY STORES INC',
#  'MOLSON COORS BEVERAGE CO',
#  'DILLARDS INC  -CL A',
#  'EXPEDITORS INTL WASH INC',
#  'FEDERAL NATIONAL MORTGA ASSN',
#  'FEDERAL REALTY INVESTMENT TR',
#  'FIRST HORIZON NATIONAL CORP',
#  'WELLTOWER INC',
#  'HOLLYFRONTIER CORP',
#  'STARWOOD HOTELS&RESORTS WRLD',
#  'HUNT (JB) TRANSPRT SVCS INC',
#  'INTL BUSINESS MACHINES CORP',
#  'INTL FLAVORS & FRAGRANCES',
#  'INTERPUBLIC GROUP OF COS',
#  'JOHNSON CONTROLS INTL PLC',
#  'KLA CORP',
#  'MARSH & MCLENNAN COS',
#  'MARSHALL & ILSLEY CORP',
#  'MASCO CORP',
#  'MEDCO HEALTH SOLUTIONS INC',
#  'ENTERGY CORP',
#  'MOLEX INC',
#  'NCR CORP',
#  'NICOR INC',
#  'ONEOK INC',
#  'PACCAR INC',
#  'PARKER-HANNIFIN CORP',
#  'PENTAIR PLC',
#  'PUBLIC SERVICE ENTRP GRP INC',
#  'ROHM AND HAAS CO',
#  'ROWAN COMPANIES PLC',
#  'SAFECO CORP',
#  'SCANA CORP',
#  'SIGMA-ALDRICH CORP',
#  'NAVIENT CORP',
#  'SUPERVALU INC',
#  'TEMPLE-INLAND INC',
#  'TERADYNE INC',
#  'ENERGY FUTURE HOLDINGS CORP',
#  'UNITED AIRLINES HOLDINGS INC',
#  'VORNADO REALTY TRUST',
#  'MEADWESTVACO CORP',
#  'WEYERHAEUSER CO',
#  'INTEGRYS HOLDING INC',
#  'XEROX HOLDINGS CORP',
#  'ZIONS BANCORPORATION NA',
#  'BEAR STEARNS COMPANIES INC',
#  'EMC CORP/MA',
#  'GENZYME CORP',
#  'HARMAN INTERNATIONAL INDS',
#  'AIRGAS INC',
#  'HEALTHPEAK PROPERTIES INC',
#  'PROGRESSIVE CORP-OHIO',
#  'BARR PHARMACEUTICALS INC',
#  'LEVEL 3 COMMUNICATIONS INC',
#  'CARNIVAL CORPORATION & PLC',
#  'ZOETIS INC',
#  'MAXIM INTEGRATED PRODUCTS',
#  'ALTERA CORP',
#  'LABORATORY CP OF AMER HLDGS',
#  'FEDERAL HOME LOAN MORTG CORP',
#  "PEOPLE'S UNITED FINL INC",
#  'COMMERCE BANCORP INC/NJ',
#  'SANTANDER HOLDINGS USA INC',
#  'IQVIA HOLDINGS INC',
#  'MALLINCKRODT PLC',
#  'DENBURY RESOURCES INC',
#  'ALLIED WASTE INDUSTRIES INC',
#  'BAXALTA INC',
#  'PMC-SIERRA INC',
#  'CEPHALON INC',
#  'AMBAC FINANCIAL GROUP INC',
#  'MGIC INVESTMENT CORP/WI',
#  'ROPER TECHNOLOGIES INC',
#  "KOHL'S CORP",
#  'COMPUWARE CORP',
#  'FOUR CORNERS PROPERTY TR INC',
#  'INGEVITY CORP',
#  'ADVANSIX INC',
#  'BROOKFIELD PROPERTY REIT',
#  'PETSMART INC',
#  'LAMB WESTON HOLDINGS INC',
#  'INCYTE CORP',
#  'CARS.COM INC',
#  'MID-AMERICA APT CMNTYS INC',
#  'QLOGIC CORP',
#  'BIOVERATIV INC',
#  'WESTROCK CO',
#  'AVALONBAY COMMUNITIES INC',
#  'AK STEEL HOLDING CORP',
#  'PROLOGIS INC',
#  'LEHMAN BROTHERS HOLDINGS INC',
#  'APARTMENT INVST & MGMT CO',
#  'AFFILIATED COMPUTER SERVICES',
#  'REALTY INCOME CORP',
#  'TECHNIPFMC PLC',
#  'BRIGHTHOUSE FINANL INC',
#  'JBG SMITH PPTYS',
#  'CHAMPIONX CORP',
#  'SUNEDISON INC',
#  'EVEREST RE GROUP LTD',
#  'DIAMOND OFFSHRE DRILLING INC',
#  'QWEST COMMUNICATION INTL INC',
#  'SANDISK CORP',
#  'UNIVISION COMMUNICATIONS INC',
#  'IMS HEALTH HOLDINGS INC',
#  'CIENA CORP',
#  'TAKE-TWO INTERACTIVE SFTWR',
#  'ALEXANDRIA R E EQUITIES INC',
#  'BROADCOM CORP',
#  'AMCOR PLC',
#  'NORWEGIAN CRUISE LINE HLDGS',
#  'CNX RESOURCES CORPORATION',
#  'SBA COMMUNICATIONS CORP',
#  'HUDSON CITY BANCORP INC',
#  'CHARTER COMMUNICATIONS INC',
#  'METLIFE INC',
#  'FRONTIER COMMUNICATIONS CORP',
#  'CENTENE CORP',
#  'TRANSDIGM GROUP INC',
#  'WYNN RESORTS LTD',
#  'QEP RESOURCES INC',
#  'ASSURANT INC',
#  'MARKETAXESS HOLDINGS INC',
#  'HOSPIRA INC',
#  'METROPCS COMMUNICATIONS INC',
#  'CF INDUSTRIES HOLDINGS INC',
#  'LEIDOS HOLDINGS INC',
#  'FIDELITY NATIONAL INFO SVCS',
#  'DIAMONDBACK ENERGY INC',
#  'EMBARQ CORP',
#  'BROADRIDGE FINANCIAL SOLUTNS',
#  'COVIDIEN PLC',
#  'TE CONNECTIVITY LTD',
#  'CAREFUSION CORP',
#  'FLEETCOR TECHNOLOGIES INC',
#  'MOTOROLA MOBILITY HLDGS INC',
#  'HUNTINGTON INGALLS IND INC',
#  'WPX ENERGY INC',
#  'FORTUNE BRANDS HOME & SECUR',
#  'CAPRI HOLDINGS LTD',
#  'LYONDELLBASELL INDUSTRIES NV']

# %%
tdf.to_csv("../output/Company_handles_tweepy_lookup_WRDSInput.csv", index=False)
